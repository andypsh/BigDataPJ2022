# %%
import pandas as pd

pd.options.display.float_format = '{:.0f}'.format

# %%
a =[]
b= 202105
c = 202100
DATE = [202105]
for i in range(11):
    b =DATE[i]+1
    if b % 100 > 12:
        b+=88
        DATE.append(b)
    else:
        DATE.append(b)
print(DATE)
# Out:
# [202105, 202106, 202107, 202108, 202109, 202110, 202111, 202112, 202201, 202202, 202203, 202204]

# %%
#print(a)
# Out:
# [202105, 202106, 202107, 202108, 202109, 202110, 202111, 202112, 202201, 202202, 202203, 202204]

# %%
for i in range(1,3):
    print(i)
# Out:
# 1
# 2

# %%
#for i in range(len(a)):
df = pd.read_csv('./지역별전력사용량_202105/202105데이터센터_전력량.csv' , encoding='cp949')
df['202105 사용량_KWH'] = df['사용량_KWH']

for i in range(1,12):
    res = pd.read_csv('./지역별전력사용량_{0}/{1}데이터센터_전력량.csv'.format(a[i] , a[i] ) , encoding='cp949')

#df.drop(['Unnamed: 0'] , axis = 1)
    res['{} 사용량_KWH'.format(a[i])]= res['사용량_KWH']
#how='inner' , on='시군구법정동번지코드'
#df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')

    df = pd.merge(df , res , how='outer' ,on='시군구법정동번지코드')
#df = df['시군구법정동번지코드' , '시도명' , '시군구명' , '법정동명' , '주소' , '이름' , '{} 사용량_KWH'.format(a[0])]




df = df[['주소_x' ,'시군구법정동번지코드', '202105 사용량_KWH' , '202106 사용량_KWH' , '202107 사용량_KWH', '202108 사용량_KWH' , '202109 사용량_KWH'
, '202110 사용량_KWH',  '202111 사용량_KWH',  '202112 사용량_KWH' ,  '202201 사용량_KWH',  '202202 사용량_KWH' , '202203 사용량_KWH' ,'202204 사용량_KWH' , '이름_x' , '기업_x' , '분류_x' ,'비고_x' ]]
df = df.drop_duplicates(['시군구법정동번지코드'])

df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6264\2887418626.py:13: FutureWarning: Passing 'suffixes' which cause duplicate columns {'주소_x', '번_x', '부번_x', '새주소대로로명_x', '임차여부_x', '시군구명_x', '기업_x', '비고_x', '법정동명_x', '이름_x', '새주소대로로코드_x', '사용량_KWH_x', '시도명_x', '지_x', '새주소부번_x', '본번_x', 'Unnamed: 0_x', '새주소본번_x', '분류_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df , res , how='outer' ,on='시군구법정동번지코드')
# C:\Users\user\AppData\Local\Temp\ipykernel_6264\2887418626.py:13: FutureWarning: Passing 'suffixes' which cause duplicate columns {'전력사용량_x', '시군구법정동번코드_y_x', '시군구법정동번코드_x_x', '시군구법정동코드_y_x', '시군구법정동코드_x_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df , res , how='outer' ,on='시군구법정동번지코드')
# ...

# %%
df.to_csv("데이터센터_연도별_전력량.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df = pd.merge(df , res , how='inner' ,on='시군구법정동번지코드')

# %%
# res = pd.read_csv('./지역별전력사용량_{0}/{1}데이터센터_전력량.csv'.format(a[2] , a[2] ) , encoding='cp949')
#
# #df.drop(['Unnamed: 0'] , axis = 1)
# res['{} 사용량_KWH'.format(a[2])]= res['사용량_KWH']
# #how='inner' , on='시군구법정동번지코드'
# #df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')
#
# df = pd.merge(df , res , how='left' ,on='시군구법정동번지코드')
# #df = df['시군구법정동번지코드' , '시도명' , '시군구명' , '법정동명' , '주소' , '이름' , '{} 사용량_KWH'.format(a[0])]
#
# df = df[['주소_x' ,'시군구법정동번지코드', '202105 사용량_KWH' , '{} 사용량_KWH'.format(a[1]) , '{} 사용량_KWH'.format(a[2])  ,  '분류_x' , '기업_x' , '이름_x'  , '비고_x']]
# df = df.drop_duplicates(['시군구법정동번지코드'])
#
# df
# Out:
#            시군구법정동번지코드  202105 사용량_KWH  202106 사용량_KWH  202107 사용량_KWH  \
# 0    4213011700204710          946923         1105552         1208055
# 8     421301170018946            2055            4958            5687
# 9     421103102210000        13400363        13158083        14898743
# 10    415701040020161            1084            1084            1084
# 11      4159013500383           48288           66696          148332
# 12   4146510300325230         1812432         1868832         1923120
# 13    414631130010218        13590708        13610076        14337699
# 21     41135109006950         1741968         1824480         2066544
# 22     41135114001922         2994192         3467376         3743712
# 23    411711010020012         4863456         4800000         5069760
# 24     41117101004101         7654680         7745160         8419080
# 25     41135107003431         2739456         2931456         2912448
# ...

# %%
# df.to_csv("데이터센터_전력량_2.csv" , mode = 'w' , encoding= 'cp949')

# %%
# res = pd.read_csv('./지역별전력사용량_{0}/{1}데이터센터_전력량.csv'.format(a[3] , a[3] ) , encoding='cp949')
#
# res
# Out:
#     Unnamed: 0        시군구법정동번지코드     시군구법정동번코드_x  시군구법정동코드_x    본번  부번  \
# 0            0   421301170018946  42130117001894  4213011700  1894   6
# 1            1  4213011700204710  42130117002047  4213011700  2047  10
# 2            2  4213011700204710  42130117002047  4213011700  2047  10
# 3            3   421103102210000  42110310221000  4211031022  1000   0
# 4            4     4159013500383    415901350038  4159013500    38   3
# ..         ...               ...             ...         ...   ...  ..
# 61          61   281101470028500  28110147002850  2811014700  2850   0
# 62          62      282601220075     28260122007  2826012200     7   5
# 63          63     4511311500862    451131150086  4511311500    86   2
# 64          64   437703302814450  43770330281445  4377033028  1445   0
# 65          65   431121060013900  43112106001390  4311210600  1390   0
#
#      사용량_KWH    시도명     시군구명     법정동명  ...  시군구법정동코드_y     번   지  \
# ...

# %%
# #df.drop(['Unnamed: 0'] , axis = 1)
# res['{} 사용량_KWH'.format(a[3])]= res['사용량_KWH']
# #how='inner' , on='시군구법정동번지코드'
# #df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')
#
# df = pd.merge(df , res , how='inner' ,on='시군구법정동번지코드')
# #df = df['시군구법정동번지코드' , '시도명' , '시군구명' , '법정동명' , '주소' , '이름' , '{} 사용량_KWH'.format(a[0])]
#
# df = df[['시군구법정동번지코드', '202105 사용량_KWH' , '{} 사용량_KWH'.format(a[1]) , '{} 사용량_KWH'.format(a[2]) , '{} 사용량_KWH'.format(a[3])  , '주소_x' , '분류_x' , '기업_x' , '이름_x'  , '비고_x']]
# df = df.drop_duplicates(['시군구법정동번지코드'])
#
# df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [122], in <cell line: 9>()
#       6 df = pd.merge(df , res , how='inner' ,on='시군구법정동번지코드')
#       7 #df = df['시군구법정동번지코드' , '시도명' , '시군구명' , '법정동명' , '주소' , '이름' , '{} 사용량_KWH'.format(a[0])]
# ----> 9 df = df[['시군구법정동번지코드', '202105 사용량_KWH' , '{} 사용량_KWH'.format(a[1]) , '{} 사용량_KWH'.format(a[2]) , '{} 사용량_KWH'.format(a[3])  , '주소_x' , '분류_x' , '기업_x' , '이름_x'  , '비고_x']]
#      10 df = df.drop_duplicates(['시군구법정동번지코드'])
#      12 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# ...
