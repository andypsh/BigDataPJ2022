# %%
import pandas as pd


df = pd.read_csv('서울특별시.csv' , encoding = 'cp949')
df_2 = pd.read_csv('../../../../데이터센터정리.csv' , encoding = 'cp949')

df = df.astype({'시군구법정동번지코드' : 'str',
                '시군구법정동번코드' : 'str'})
df.head()
# Out:
#    Unnamed: 0       시군구법정동번지코드      시군구법정동번코드    시군구법정동코드   본번   부번  사용량_KWH  \
# 0           0   11110101003100    11110101003  1111010100    3  100     3329
# 1      126454    1168011100115    11680111001  1168011100    1   15      429
# 2       66833  113501050016987  1135010500169  1135010500  169   87     3773
# 3       66832  113501050016975  1135010500169  1135010500  169   75     8043
# 4       66831  113501050016958  1135010500169  1135010500  169   58     1557
#
#      시도명 시군구명 법정동명        새주소대로로코드    새주소대로로명  새주소본번 새주소부번
# 0  서울특별시  종로구  청운동  111103100014.0       창의문로  119.0   0.0
# 1  서울특별시  강남구  세곡동               -          -      -     -
# 2  서울특별시  노원구  상계동  113504130395.0   한글비석로23길   10.0   0.0
# 3  서울특별시  노원구  상계동  113503110009.0      한글비석로  422.0   0.0
# 4  서울특별시  노원구  상계동  113504130396.0  한글비석로24가길   11.0   0.0

# %%
df_2.head()
# Out:
#          시군구법정동번지코드       시군구법정동번코드    시군구법정동코드     번   지  \
# 0   421301170018946  42130117001894  4213011700  1894   6
# 1  4213011700204710  42130117002047  4213011700  2047  14
# 2  4213011700204710  42130117002047  4213011700  2047  10
# 3   421103102210000  42110310221000  4211031022  1000   0
# 4    42110126006500   4211012600650  4211012600   650   0
#
#                             주소  분류         기업                       이름  \
# 0    강원 원주시 건강로 32(반곡동 1894-6)  공공   국민건강보험공단           국민건강보험공단 데이터센터
# 1  강원 원주시 입춘로 130(반곡동 2047-14)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (2사옥)
# 2   강원 원주시 혁신로 60(반곡동 2047-10)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (1사옥)
# 3          강원 춘천시 동면 순환대로 1231  민간      NAVER              네이버 데이터센터 각
# 4          강원도 춘천시 옛경춘로 409-14  민간     오라클 춘천                   오라클 춘천
#
#                         비고 임차여부  전력사용량
# 0               O 자체 데이터센터    -    NaN
# 1                        -    -    NaN
# 2                        -    -    NaN
# 3  수력 발전소 통해 전체 전력량 70% 수급    -    NaN
# 4                        -    -    NaN

# %%
df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')

df_3
# Out:
#     Unnamed: 0       시군구법정동번지코드     시군구법정동번코드_x  시군구법정동코드_x    본번  부번  \
# 0        71540  114401270015970  11440127001597  1144012700  1597   0
# 1        73726  114401270015860  11440127001586  1144012700  1586   0
# 2        73979   11470102009244   1147010200924  1147010200   924   4
# 3       116995   11680101006753   1168010100675  1168010100   675   3
# 4       125329   11680108002611   1168010800261  1168010800   261   1
# 5       101479   11545101004599   1154510100459  1154510100   459   9
# 6       101911   11545101005332   1154510100533  1154510100   533   2
# 7        87228  114401270016000  11440127001600  1144012700  1600   0
# 8        87345  114401270015850  11440127001585  1144012700  1585   0
# 9        85844   11545101006029    115451010060  1154510100    60  29
# 10       83331  115301020019712   1153010200197  1153010200   197  12
# 11       83331  115301020019712   1153010200197  1153010200   197  12
# 12       81255   11440109001689   1144010900168  1144010900   168   9
# 13      114538  116501080014211  11650108001421  1165010800  1421   1
# 14      128561  116501080014231  11650108001423  1165010800  1423   1
# 15      129809  116501080017101  11650108001710  1165010800  1710   1
# 16      141043   11680118004676   1168011800467  1168011800   467   6
# 17       11973     111701170012     11170117001  1117011700     1   2
# 18       18674   11215101003080    112151010030  1121510100    30  80
#
#      사용량_KWH    시도명 시군구명   법정동명  ...  시군구법정동코드_y     번   지  \
# 0     425196  서울특별시  마포구    상암동  ...  1144012700  1597   0
# 1    5120973  서울특별시  마포구    상암동  ...  1144012700  1586   0
# 2   16889496  서울특별시  양천구     목동  ...  1147010200   924   4
# 3     222885  서울특별시  강남구    역삼동  ...  1168010100   675   3
# 4    5831015  서울특별시  강남구    논현동  ...  1168010800   261   1
# 5   14782320  서울특별시  금천구    가산동  ...  1154510100   459   9
# 6    2344080  서울특별시  금천구    가산동  ...  1154510100   533   2
# 7    5356944  서울특별시  마포구    상암동  ...  1144012700  1600   0
# 8    2891433  서울특별시  마포구    상암동  ...  1144012700  1585   0
# 9    1641920  서울특별시  금천구    가산동  ...  1154510100    60  29
# 10   1925991  서울특별시  구로구    구로동  ...  1153010200   197  12
# 11   1925991  서울특별시  구로구    구로동  ...  1153010200   197  12
# 12    982560  서울특별시  마포구    염리동  ...  1144010900   168   9
# 13   1320960  서울특별시  서초구    서초동  ...  1165010800  1421   1
# 14   1942239  서울특별시  서초구    서초동  ...  1165010800  1423   1
# 15   6488033  서울특별시  서초구    서초동  ...  1165010800  1710   1
# 16   1452306  서울특별시  강남구    도곡동  ...  1168011800   467   6
# 17   5877060  서울특별시  용산구  원효로3가  ...  1117011700     1   2
# 18    453022  서울특별시  광진구    중곡동  ...  1121510100    30  80
#
#                                             주소  분류  \
# 0             서울 마포구 월드컵북로54길 17 사보이시티 오피스동 4층  공공
# 1   서울 특별시 마포구 월드컵북로 60길 24,서울특별시 마포구 상암동 1586  민간
# 2                서울시 양천구 목동동로 233-5 (목동 924-4)  통신
# 3                서울특별시 강남구 언주로 517 (역삼동 675-3)  통신
# 4                      서울특별시 강남구 언주로 616 (논현동)  통신
# 5            서울특별시 금천구 가산디지털1로 189 (가산동 459-9)  통신
# 6                          서울특별시 구로구 가산동 533-2  민간
# 7                서울특별시 마포구 월드컵북로 416(상암동 1600)  통신
# 8                         서울시 마포구 월드컵북로 60길 17  금융
# 9                서울특별시 금천구 가산동 60-29(가산로9길 80)  통신
# 10                          서울 구로구 디지털로 31길 61  민간
# 11            서울특별시 구로구 디지털로 31길 61 KT IDC 남구로  통신
# 12                     서울특별시 마포구 독막로 311 재화스퀘어  민간
# 13             서울 서초구 남부순환로337가길 40(서초동1421-1)  통신
# 14            서울특별시 서초구 남부순환로 2481(서초동 1423-1)  통신
# 15   서울특별시 서초구 법원로 1길 6 (서울특별시 서초구 서초동 1710-1)  통신
# 16              서울특별시 강남구 언주로 30길 13 대림아크로텔 5층  민간
# 17                    서울 용산구 원효로41길 33 KT국제전화국  통신
# 18       서울 광진구 능동로 400 보건복지행정타운 20층 한국사회보장정보원  공공
#
#                                                    기업               이름  \
# 0                                            한국주택금융공사  한국주택금융공사 상암IT센터
# 1   삼성SDS,KINX,에퀴닉스(리츠) (SL1 서울 Equinix Internatio...     삼성SDS 상암IT센터
# 2                                     KT,AWS, 메리츠금융그룹       KT 목동IDC 1
# 3                                                  KT         KT 강남IDC
# 4                                               LG U+        LG U+논현센터
# 5                                  LG U+, LG CNS,KINX        LG U+가산센터
# 6                                              롯데정보통신      롯데정보통신 제1센터
# 7                                               LG U+        LG U+상암센터
# 8                                                우리금융       우리금융 데이터센터
# 9                                             SK브로드밴드             가산센터
# 10                                               알리바바             알리바바
# 11                                                 KT       KT 남구로 IDC
# 12                                               다우기술  다우IDC 제 1센터(마포)
# 13                                              LG U+      LG U+서초 2센터
# 14                                              LG U+      LG U+서초 1센터
# 15                 SK브로드밴드,다우기술(제2센터),코레일관광개발(주) (공공)             서초센터
# 16                                  KINX (인터넷 인프라 기업)       IDC 도곡 1센터
# 17                                                 KT        KT 용산 IDC
# 18                                          한국사회보장정보원  한국사회보장정보원 데이터센터
#
#                                      비고 임차여부 전력사용량
# 0                                     -    -   NaN
# 1                                     -    -   NaN
# 2                                     -    -   NaN
# 3                                     -    -   NaN
# 4                                     -    -   NaN
# 5                                     -    -   NaN
# 6                                     -    -   NaN
# 7                                     -    -   NaN
# 8                                     -    -   NaN
# 9                                     -    -   NaN
# 10                                    -    -   NaN
# 11                                    -    -   NaN
# 12                                    -    -   NaN
# 13                                    -    -   NaN
# 14                                    -    -   NaN
# 15                                    -    -   NaN
# 16  KINX는 호스트웨이, LG CNS등의 기업을 임차하여 사용 중    -   NaN
# 17                                    -    -   NaN
# 18                                    -    -   NaN
#
# [19 rows x 25 columns]

# %%
df_3.to_csv("서울특별시_전력사용량.csv" , mode = 'w' , encoding= 'cp949')
