# %%
import pandas as pd
import re

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ### 1. 꼭 read_csv 21상반기, 19하반기와 같이 맞추어 주세요!!! 또한 지역(전라북도, 남도) 맞추기!!!!!

# %%
df = pd.read_csv('울산광역시_계약종별 전력사용량 월별_14하반기.csv' , encoding='cp949')

df
#exchng=  pd.read_csv('지역별_전력거래량_20220803093050.csv' , encoding='cp949')
# Out:
#         계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0    시도 : 울산광역시, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1        기간 : 2014년 07 월 ~ 2014년 12월        NaN            NaN        NaN
# 2                                 년월         시구            시군구       계약구분
# 3                             201407      울산광역시  전체(시 / 군 / 구)        주택용
# 4                             201407      울산광역시  전체(시 / 군 / 구)        일반용
# ..                               ...        ...            ...        ...
# 283                           201412      울산광역시             중구        산업용
# 284                           201412      울산광역시             중구        심 야
# 285                           201412      울산광역시             중구        일반용
# 286                           201412      울산광역시             중구        주택용
# 287                           201412      울산광역시             중구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0          NaN           NaN              NaN            NaN
# 1          NaN           NaN              NaN            NaN
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     299,537   115,274,553   13,818,278,155          119.9
# 4      67,329   160,172,306   24,341,965,622          152.0
# ..         ...           ...              ...            ...
# 283       516     2,159,796      302,795,364          140.2
# 284       786     1,771,195      134,759,537           76.1
# 285    12,993    25,914,302    3,674,136,311          141.8
# 286    68,600    25,532,563    3,337,481,203          130.7
# 287    88,388    58,318,539    7,767,330,229          133.2
#
# [288 rows x 8 columns]

# %%
df = df.drop([0,1 , 46] , axis = 0)
#0,1 , 10은 지우는게 맞다
df
# Out:
#     계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 2                             년월         시구            시군구       계약구분
# 3                         201407      울산광역시  전체(시 / 군 / 구)        주택용
# 4                         201407      울산광역시  전체(시 / 군 / 구)        일반용
# 5                         201407      울산광역시  전체(시 / 군 / 구)        교육용
# 6                         201407      울산광역시  전체(시 / 군 / 구)        산업용
# ..                           ...        ...            ...        ...
# 283                       201412      울산광역시             중구        산업용
# 284                       201412      울산광역시             중구        심 야
# 285                       201412      울산광역시             중구        일반용
# 286                       201412      울산광역시             중구        주택용
# 287                       201412      울산광역시             중구         합계
#
#     Unnamed: 4      Unnamed: 5        Unnamed: 6     Unnamed: 7
# 2      고객호수(호)        사용량(kWh)           전기요금(원)  평균판매단가(원/kWh)
# 3     299,537     115,274,553    13,818,278,155          119.9
# 4      67,329     160,172,306    24,341,965,622          152.0
# 5         421      13,018,084     1,665,891,028          128.0
# 6       5,962   2,286,035,755   257,423,954,404          112.6
# ..         ...             ...               ...            ...
# 283       516       2,159,796       302,795,364          140.2
# 284       786       1,771,195       134,759,537           76.1
# 285    12,993      25,914,302     3,674,136,311          141.8
# 286    68,600      25,532,563     3,337,481,203          130.7
# 287    88,388      58,318,539     7,767,330,229          133.2
#
# [285 rows x 8 columns]

# %%
a= df.loc[2].tolist()
a
df = df.drop([2] , axis = 0)

# %%
df.columns = a
df
# Out:
#          년월     시구            시군구 계약구분   고객호수(호)        사용량(kWh)  \
# 3    201407  울산광역시  전체(시 / 군 / 구)  주택용  299,537     115,274,553
# 4    201407  울산광역시  전체(시 / 군 / 구)  일반용   67,329     160,172,306
# 5    201407  울산광역시  전체(시 / 군 / 구)  교육용      421      13,018,084
# 6    201407  울산광역시  전체(시 / 군 / 구)  산업용    5,962   2,286,035,755
# 7    201407  울산광역시  전체(시 / 군 / 구)  농사용   10,806       6,165,825
# ..      ...    ...            ...  ...       ...             ...
# 283  201412  울산광역시             중구  산업용      516       2,159,796
# 284  201412  울산광역시             중구  심 야      786       1,771,195
# 285  201412  울산광역시             중구  일반용   12,993      25,914,302
# 286  201412  울산광역시             중구  주택용   68,600      25,532,563
# 287  201412  울산광역시             중구   합계   88,388      58,318,539
#
#               전기요금(원) 평균판매단가(원/kWh)
# 3     13,818,278,155         119.9
# 4     24,341,965,622         152.0
# 5      1,665,891,028         128.0
# 6    257,423,954,404         112.6
# 7        310,920,912          50.4
# ..                ...           ...
# 283      302,795,364         140.2
# 284      134,759,537          76.1
# 285    3,674,136,311         141.8
# 286    3,337,481,203         130.7
# 287    7,767,330,229         133.2
#
# [284 rows x 8 columns]

# %%
df_2 = df.loc[:45]
df_2
# Out:
#         년월     시구            시군구 계약구분    고객호수(호)        사용량(kWh)  \
# 3   201407  울산광역시  전체(시 / 군 / 구)  주택용   299,537     115,274,553
# 4   201407  울산광역시  전체(시 / 군 / 구)  일반용    67,329     160,172,306
# 5   201407  울산광역시  전체(시 / 군 / 구)  교육용       421      13,018,084
# 6   201407  울산광역시  전체(시 / 군 / 구)  산업용     5,962   2,286,035,755
# 7   201407  울산광역시  전체(시 / 군 / 구)  농사용    10,806       6,165,825
# 8   201407  울산광역시  전체(시 / 군 / 구)  가로등    29,822       3,989,490
# 9   201407  울산광역시  전체(시 / 군 / 구)  심 야     8,498       5,912,580
# 10  201408  울산광역시  전체(시 / 군 / 구)  주택용   300,538     134,903,110
# 11  201408  울산광역시  전체(시 / 군 / 구)  일반용    67,453     183,420,770
# 12  201408  울산광역시  전체(시 / 군 / 구)  교육용       419      12,490,894
# 13  201408  울산광역시  전체(시 / 군 / 구)  산업용     5,976   2,205,874,027
# 14  201408  울산광역시  전체(시 / 군 / 구)  농사용    10,891       7,569,772
# 15  201408  울산광역시  전체(시 / 군 / 구)  가로등    29,887       4,269,637
# 16  201408  울산광역시  전체(시 / 군 / 구)  심 야     8,454       5,219,833
# 17  201409  울산광역시  전체(시 / 군 / 구)  주택용   301,490     121,607,959
# 18  201409  울산광역시  전체(시 / 군 / 구)  일반용    67,483     159,826,126
# 19  201409  울산광역시  전체(시 / 군 / 구)  교육용       418      11,715,893
# 20  201409  울산광역시  전체(시 / 군 / 구)  산업용     5,984   2,142,818,537
# 21  201409  울산광역시  전체(시 / 군 / 구)  농사용    10,992       7,603,612
# 22  201409  울산광역시  전체(시 / 군 / 구)  가로등    29,919       4,543,357
# 23  201409  울산광역시  전체(시 / 군 / 구)  심 야     8,432       5,255,365
# 24  201410  울산광역시  전체(시 / 군 / 구)  주택용   302,231     112,292,186
# 25  201410  울산광역시  전체(시 / 군 / 구)  일반용    67,476     142,456,356
# 26  201410  울산광역시  전체(시 / 군 / 구)  교육용       418      10,440,869
# 27  201410  울산광역시  전체(시 / 군 / 구)  산업용     5,993   2,236,405,885
# 28  201410  울산광역시  전체(시 / 군 / 구)  농사용    11,022       6,166,353
# 29  201410  울산광역시  전체(시 / 군 / 구)  가로등    29,969       4,910,874
# 30  201410  울산광역시  전체(시 / 군 / 구)  심 야     8,406       6,637,574
# 31  201411  울산광역시  전체(시 / 군 / 구)  주택용   303,327     119,768,753
# 32  201411  울산광역시  전체(시 / 군 / 구)  일반용    67,745     143,865,589
# 33  201411  울산광역시  전체(시 / 군 / 구)  교육용       419      11,232,473
# 34  201411  울산광역시  전체(시 / 군 / 구)  산업용     6,015   2,134,640,843
# 35  201411  울산광역시  전체(시 / 군 / 구)  농사용    11,973       7,245,952
# 36  201411  울산광역시  전체(시 / 군 / 구)  가로등    30,018       5,380,507
# 37  201411  울산광역시  전체(시 / 군 / 구)  심 야     8,379      12,457,786
# 38  201412  울산광역시  전체(시 / 군 / 구)  주택용   303,949     124,375,943
# 39  201412  울산광역시  전체(시 / 군 / 구)  일반용    68,023     162,304,324
# 40  201412  울산광역시  전체(시 / 군 / 구)  교육용       419      15,837,322
# 41  201412  울산광역시  전체(시 / 군 / 구)  산업용     6,020   2,280,289,791
# 42  201412  울산광역시  전체(시 / 군 / 구)  농사용    11,002       6,989,200
# 43  201412  울산광역시  전체(시 / 군 / 구)  가로등    30,073       5,561,820
# 44  201412  울산광역시  전체(시 / 군 / 구)  심 야     8,349      19,074,846
# 45      합계     합계             합계   합계  2,551,937  15,166,022,731
#
#               전기요금(원) 평균판매단가(원/kWh)
# 3     13,818,278,155         119.9
# 4     24,341,965,622         152.0
# 5      1,665,891,028         128.0
# 6    257,423,954,404         112.6
# 7        310,920,912          50.4
# 8        498,604,993         125.0
# 9        338,377,110          57.2
# 10    18,729,458,977         138.8
# 11    26,756,455,943         145.9
# 12     1,596,614,377         127.8
# 13   239,466,906,998         108.6
# 14       372,025,939          49.1
# 15       510,098,460         119.5
# 16       301,396,342          57.7
# 17    15,250,035,350         125.4
# 18    21,297,582,557         133.3
# 19     1,267,191,332         108.2
# 20   185,525,778,562          86.6
# 21       372,527,958          49.0
# 22       523,393,517         115.2
# 23       301,325,340          57.3
# 24    13,006,155,328         115.8
# 25    16,947,250,892         119.0
# 26     1,073,997,340         102.9
# 27   191,773,568,673          85.8
# 28       311,046,049          50.4
# 29       534,628,158         108.9
# 30       368,602,798          55.5
# 31    14,639,329,016         122.2
# 32    19,116,655,897         132.9
# 33     1,299,578,243         115.7
# 34   232,222,404,277         108.8
# 35       352,657,858          48.7
# 36       568,943,044         105.7
# 37       789,272,854          63.4
# 38    15,731,447,537         126.5
# 39    22,986,793,111         141.6
# 40     1,745,582,949         110.2
# 41   248,318,463,865         108.9
# 42       352,139,577          50.4
# 43       573,409,872         103.1
# 44     1,441,114,505          75.6
# 45  1,594,821,825,719         105.2

# %%
GyeonGi  = df_2.loc[(df_2['계약구분'] == '일반용')]
#SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
GyeonGi
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\730399353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
#         년월     시구 계약구분  고객호수(호)      사용량(kWh)
# 4   201407  울산광역시  일반용  67,329   160,172,306
# 11  201408  울산광역시  일반용  67,453   183,420,770
# 18  201409  울산광역시  일반용  67,483   159,826,126
# 25  201410  울산광역시  일반용  67,476   142,456,356
# 32  201411  울산광역시  일반용  67,745   143,865,589
# 39  201412  울산광역시  일반용  68,023   162,304,324

# %%
#SEOUL1.to_csv("서울특별시_계약종별_전국_전력사용량_2022.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df_2.to_csv("서울특별시_계약종별_전국_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
df_3 = df.loc[48:]
df_3 = df_3.loc[(df_3['계약구분'] == '일반용')]
df_3 = df_3.sort_values(by=['시군구' , '년월'])
df_3.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_3
# Out:
#          년월     시구  시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201407  울산광역시   남구  일반용  24,809   64,737,661
# 93   201408  울산광역시   남구  일반용  24,796   75,354,519
# 133  201409  울산광역시   남구  일반용  24,795   64,249,304
# 173  201410  울산광역시   남구  일반용  24,779   56,272,768
# 213  201411  울산광역시   남구  일반용  24,843   55,841,644
# 253  201412  울산광역시   남구  일반용  24,924   63,283,766
# 61   201407  울산광역시   동구  일반용   8,027   20,294,267
# 101  201408  울산광역시   동구  일반용   8,036   22,495,789
# 141  201409  울산광역시   동구  일반용   8,050   20,412,004
# 181  201410  울산광역시   동구  일반용   8,054   18,290,411
# 221  201411  울산광역시   동구  일반용   8,070   17,881,918
# 261  201412  울산광역시   동구  일반용   8,086   19,789,762
# 69   201407  울산광역시   북구  일반용   7,871   21,481,346
# 109  201408  울산광역시   북구  일반용   7,895   23,791,191
# 149  201409  울산광역시   북구  일반용   7,899   21,051,849
# 189  201410  울산광역시   북구  일반용   7,914   19,027,978
# 229  201411  울산광역시   북구  일반용   7,963   19,610,006
# 269  201412  울산광역시   북구  일반용   8,024   22,510,052
# 77   201407  울산광역시  울주군  일반용  13,845   27,872,417
# 117  201408  울산광역시  울주군  일반용  13,896   32,049,639
# 157  201409  울산광역시  울주군  일반용  13,903   28,475,052
# 197  201410  울산광역시  울주군  일반용  13,895   25,962,206
# 237  201411  울산광역시  울주군  일반용  13,939   27,719,262
# 277  201412  울산광역시  울주군  일반용  13,996   30,806,442
# 85   201407  울산광역시   중구  일반용  12,777   25,786,615
# 125  201408  울산광역시   중구  일반용  12,830   29,729,632
# 165  201409  울산광역시   중구  일반용  12,836   25,637,917
# 205  201410  울산광역시   중구  일반용  12,834   22,902,993
# 245  201411  울산광역시   중구  일반용  12,930   22,812,759
# 285  201412  울산광역시   중구  일반용  12,993   25,914,302

# %%
a = df_3.loc[: , "시구"]
b = a[:1].tolist()
for i in b:
    City = i
City
# Out:
# '울산광역시'

# %%
SIGUNGU = list(set(df_3.loc[: , '시군구'].tolist()))
SIGUNGU.sort()
SIGUNGU
# Out:
# ['남구', '동구', '북구', '울주군', '중구']

# %%
df_4 = df.loc[48:]
df_4 = df_4.loc[(df_4['계약구분'] == '합계')]
df_4 = df_4.sort_values(by=['시군구' , '년월'])
df_4.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_4
# Out:
#          년월     시구  시군구 계약구분   고객호수(호)        사용량(kWh)
# 55   201407  울산광역시   남구   합계  131,470   1,295,643,113
# 95   201408  울산광역시   남구   합계  131,509   1,311,967,389
# 135  201409  울산광역시   남구   합계  131,637   1,242,585,179
# 175  201410  울산광역시   남구   합계  131,731   1,245,803,734
# 215  201411  울산광역시   남구   합계  132,081   1,177,720,036
# 255  201412  울산광역시   남구   합계  132,328   1,289,657,206
# 63   201407  울산광역시   동구   합계   55,663     168,533,024
# 103  201408  울산광역시   동구   합계   56,039     146,264,514
# 143  201409  울산광역시   동구   합계   56,382     147,225,529
# 183  201410  울산광역시   동구   합계   56,562     147,377,014
# 223  201411  울산광역시   동구   합계   56,860     144,058,296
# 263  201412  울산광역시   동구   합계   57,060     160,629,107
# 71   201407  울산광역시   북구   합계   45,997     216,630,933
# 111  201408  울산광역시   북구   합계   46,101     185,703,036
# 151  201409  울산광역시   북구   합계   46,307     173,215,138
# 191  201410  울산광역시   북구   합계   46,472     198,419,930
# 231  201411  울산광역시   북구   합계   46,874     200,453,412
# 271  201412  울산광역시   북구   합계   46,738     222,957,840
# 79   201407  울산광역시  울주군   합계  101,852     856,216,306
# 119  201408  울산광역시  울주군   합계  102,327     847,897,995
# 159  201409  울산광역시  울주군   합계  102,561     835,546,228
# 199  201410  울산광역시  울주군   합계  102,800     877,601,710
# 239  201411  울산광역시  울주군   합계  103,869     859,786,068
# 279  201412  울산광역시  울주군   합계  103,321     882,870,554
# 87   201407  울산광역시   중구   합계   87,393      53,545,217
# 127  201408  울산광역시   중구   합계   87,642      61,915,109
# 167  201409  울산광역시   중구   합계   87,831      54,798,775
# 207  201410  울산광역시   중구   합계   87,950      50,107,709
# 247  201411  울산광역시   중구   합계   88,192      52,574,091
# 287  201412  울산광역시   중구   합계   88,388      58,318,539

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_4['사용량(kWh)'].loc[(df_4['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_4['고객호수(호)'].loc[(df_4['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//36) #6개월 치로 나눠야하나?!




print("{} 지역별 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# Out:
# [1295643113, 1311967389, 1242585179, 1245803734, 1177720036, 1289657206]
# [168533024, 146264514, 147225529, 147377014, 144058296, 160629107]
# [216630933, 185703036, 173215138, 198419930, 200453412, 222957840]
# [856216306, 847897995, 835546228, 877601710, 859786068, 882870554]
# [53545217, 61915109, 54798775, 50107709, 52574091, 58318539]
# 울산광역시 지역별 합계 :  [7563376657, 914087484, 1197380289, 5159918861, 331259440]
# 울산광역시 고객호수 평균:  [21965, 9404, 7735, 17131, 14649]

# %% [markdown]
# ### 2. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = df_4.copy()
Hap.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    Hap = Hap.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
Hap
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\527191269.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\527191269.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\527191269.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\527191269.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\527191269.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                년월     시구  시군구 계약구분   고객호수(호)        사용량(kWh)
# 0          201407  울산광역시   남구   합계  131,470   1,295,643,113
# 1          201408  울산광역시   남구   합계  131,509   1,311,967,389
# 2          201409  울산광역시   남구   합계  131,637   1,242,585,179
# 3          201410  울산광역시   남구   합계  131,731   1,245,803,734
# 4          201411  울산광역시   남구   합계  132,081   1,177,720,036
# 5          201412  울산광역시   남구   합계  132,328   1,289,657,206
# 6          201407  울산광역시   동구   합계   55,663     168,533,024
# 7          201408  울산광역시   동구   합계   56,039     146,264,514
# 8          201409  울산광역시   동구   합계   56,382     147,225,529
# 9          201410  울산광역시   동구   합계   56,562     147,377,014
# 10         201411  울산광역시   동구   합계   56,860     144,058,296
# 11         201412  울산광역시   동구   합계   57,060     160,629,107
# 12         201407  울산광역시   북구   합계   45,997     216,630,933
# 13         201408  울산광역시   북구   합계   46,101     185,703,036
# 14         201409  울산광역시   북구   합계   46,307     173,215,138
# 15         201410  울산광역시   북구   합계   46,472     198,419,930
# 16         201411  울산광역시   북구   합계   46,874     200,453,412
# 17         201412  울산광역시   북구   합계   46,738     222,957,840
# 18         201407  울산광역시  울주군   합계  101,852     856,216,306
# 19         201408  울산광역시  울주군   합계  102,327     847,897,995
# 20         201409  울산광역시  울주군   합계  102,561     835,546,228
# 21         201410  울산광역시  울주군   합계  102,800     877,601,710
# 22         201411  울산광역시  울주군   합계  103,869     859,786,068
# 23         201412  울산광역시  울주군   합계  103,321     882,870,554
# 24         201407  울산광역시   중구   합계   87,393      53,545,217
# 25         201408  울산광역시   중구   합계   87,642      61,915,109
# 26         201409  울산광역시   중구   합계   87,831      54,798,775
# 27         201410  울산광역시   중구   합계   87,950      50,107,709
# 28         201411  울산광역시   중구   합계   88,192      52,574,091
# 29         201412  울산광역시   중구   합계   88,388      58,318,539
# 30  201407-201412  울산광역시   남구   합계     21965      7563376657
# 31  201407-201412  울산광역시   동구   합계      9404       914087484
# 32  201407-201412  울산광역시   북구   합계      7735      1197380289
# 33  201407-201412  울산광역시  울주군   합계     17131      5159918861
# 34  201407-201412  울산광역시   중구   합계     14649       331259440

# %% [markdown]
# ### 3. 날짜 변경!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = Hap.loc[Hap['년월'] == '201407-201412']
Hap
# Out:
#                년월     시구  시군구 계약구분 고객호수(호)    사용량(kWh)
# 30  201407-201412  울산광역시   남구   합계   21965  7563376657
# 31  201407-201412  울산광역시   동구   합계    9404   914087484
# 32  201407-201412  울산광역시   북구   합계    7735  1197380289
# 33  201407-201412  울산광역시  울주군   합계   17131  5159918861
# 34  201407-201412  울산광역시   중구   합계   14649   331259440

# %%
# SIGUNGU = SIGUNGU[:1]
# SIGUNGU
#for i in SIGUNGU:
#print('{}'.format(i))
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
a = (df_3.columns).tolist()

a
# Out:
# ['년월', '시구', '시군구', '계약구분', '고객호수(호)', '사용량(kWh)']

# %%
df_3
# Out:
#          년월     시구  시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201407  울산광역시   남구  일반용  24,809   64,737,661
# 93   201408  울산광역시   남구  일반용  24,796   75,354,519
# 133  201409  울산광역시   남구  일반용  24,795   64,249,304
# 173  201410  울산광역시   남구  일반용  24,779   56,272,768
# 213  201411  울산광역시   남구  일반용  24,843   55,841,644
# 253  201412  울산광역시   남구  일반용  24,924   63,283,766
# 61   201407  울산광역시   동구  일반용   8,027   20,294,267
# 101  201408  울산광역시   동구  일반용   8,036   22,495,789
# 141  201409  울산광역시   동구  일반용   8,050   20,412,004
# 181  201410  울산광역시   동구  일반용   8,054   18,290,411
# 221  201411  울산광역시   동구  일반용   8,070   17,881,918
# 261  201412  울산광역시   동구  일반용   8,086   19,789,762
# 69   201407  울산광역시   북구  일반용   7,871   21,481,346
# 109  201408  울산광역시   북구  일반용   7,895   23,791,191
# 149  201409  울산광역시   북구  일반용   7,899   21,051,849
# 189  201410  울산광역시   북구  일반용   7,914   19,027,978
# 229  201411  울산광역시   북구  일반용   7,963   19,610,006
# 269  201412  울산광역시   북구  일반용   8,024   22,510,052
# 77   201407  울산광역시  울주군  일반용  13,845   27,872,417
# 117  201408  울산광역시  울주군  일반용  13,896   32,049,639
# 157  201409  울산광역시  울주군  일반용  13,903   28,475,052
# 197  201410  울산광역시  울주군  일반용  13,895   25,962,206
# 237  201411  울산광역시  울주군  일반용  13,939   27,719,262
# 277  201412  울산광역시  울주군  일반용  13,996   30,806,442
# 85   201407  울산광역시   중구  일반용  12,777   25,786,615
# 125  201408  울산광역시   중구  일반용  12,830   29,729,632
# 165  201409  울산광역시   중구  일반용  12,836   25,637,917
# 205  201410  울산광역시   중구  일반용  12,834   22,902,993
# 245  201411  울산광역시   중구  일반용  12,930   22,812,759
# 285  201412  울산광역시   중구  일반용  12,993   25,914,302

# %%
# GyeonGiHap = pd.DataFrame([] , columns = a)
# GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{가평군}')]
# GyeonGiHap

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_3['고객호수(호)'].loc[(df_3['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//6) #6개월 치로 나눠야하나?!




print("{} 지역별 일반용 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# GyeonGiHap['합계'] = sum
#
# GyeonGiHap
# Out:
# [64737661, 75354519, 64249304, 56272768, 55841644, 63283766]
# [20294267, 22495789, 20412004, 18290411, 17881918, 19789762]
# [21481346, 23791191, 21051849, 19027978, 19610006, 22510052]
# [27872417, 32049639, 28475052, 25962206, 27719262, 30806442]
# [25786615, 29729632, 25637917, 22902993, 22812759, 25914302]
# 울산광역시 지역별 일반용 합계 :  [379739662, 119164151, 127472422, 172885018, 152784218]
# 울산광역시 고객호수 평균:  [24824, 8053, 7927, 13912, 12866]

# %%
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
# GyeonGiHap = df_3.copy()
# GyeonGiHap.reset_index(drop=True , inplace = True)
# GyeonGiHap.append({'년월' : '202107-202112'  , '시구' : '경기도' , '시군구' : '가평군' , '계약구분' : '일반용' , '사용량(kWh)' : sum}, ignore_index=True)

# %%
# a=[]
# for i in SIGUNGU:
#     a.append(i)
#
# print(a)

# %% [markdown]
# ### 4. 년월 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = df_3.copy()
GyeonGiHap2.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
GyeonGiHap2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\422212722.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\422212722.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\422212722.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\422212722.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\422212722.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201407-201412'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                년월     시구  시군구 계약구분  고객호수(호)     사용량(kWh)
# 0          201407  울산광역시   남구  일반용  24,809   64,737,661
# 1          201408  울산광역시   남구  일반용  24,796   75,354,519
# 2          201409  울산광역시   남구  일반용  24,795   64,249,304
# 3          201410  울산광역시   남구  일반용  24,779   56,272,768
# 4          201411  울산광역시   남구  일반용  24,843   55,841,644
# 5          201412  울산광역시   남구  일반용  24,924   63,283,766
# 6          201407  울산광역시   동구  일반용   8,027   20,294,267
# 7          201408  울산광역시   동구  일반용   8,036   22,495,789
# 8          201409  울산광역시   동구  일반용   8,050   20,412,004
# 9          201410  울산광역시   동구  일반용   8,054   18,290,411
# 10         201411  울산광역시   동구  일반용   8,070   17,881,918
# 11         201412  울산광역시   동구  일반용   8,086   19,789,762
# 12         201407  울산광역시   북구  일반용   7,871   21,481,346
# 13         201408  울산광역시   북구  일반용   7,895   23,791,191
# 14         201409  울산광역시   북구  일반용   7,899   21,051,849
# 15         201410  울산광역시   북구  일반용   7,914   19,027,978
# 16         201411  울산광역시   북구  일반용   7,963   19,610,006
# 17         201412  울산광역시   북구  일반용   8,024   22,510,052
# 18         201407  울산광역시  울주군  일반용  13,845   27,872,417
# 19         201408  울산광역시  울주군  일반용  13,896   32,049,639
# 20         201409  울산광역시  울주군  일반용  13,903   28,475,052
# 21         201410  울산광역시  울주군  일반용  13,895   25,962,206
# 22         201411  울산광역시  울주군  일반용  13,939   27,719,262
# 23         201412  울산광역시  울주군  일반용  13,996   30,806,442
# 24         201407  울산광역시   중구  일반용  12,777   25,786,615
# 25         201408  울산광역시   중구  일반용  12,830   29,729,632
# 26         201409  울산광역시   중구  일반용  12,836   25,637,917
# 27         201410  울산광역시   중구  일반용  12,834   22,902,993
# 28         201411  울산광역시   중구  일반용  12,930   22,812,759
# 29         201412  울산광역시   중구  일반용  12,993   25,914,302
# 30  201407-201412  울산광역시   남구  일반용    24824    379739662
# 31  201407-201412  울산광역시   동구  일반용     8053    119164151
# 32  201407-201412  울산광역시   북구  일반용     7927    127472422
# 33  201407-201412  울산광역시  울주군  일반용    13912    172885018
# 34  201407-201412  울산광역시   중구  일반용    12866    152784218

# %% [markdown]
# ### 5. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = GyeonGiHap2.loc[GyeonGiHap2['년월'] == '201407-201412']
GyeonGiHap2
# Out:
#                년월     시구  시군구 계약구분 고객호수(호)   사용량(kWh)
# 30  201407-201412  울산광역시   남구  일반용   24824  379739662
# 31  201407-201412  울산광역시   동구  일반용    8053  119164151
# 32  201407-201412  울산광역시   북구  일반용    7927  127472422
# 33  201407-201412  울산광역시  울주군  일반용   13912  172885018
# 34  201407-201412  울산광역시   중구  일반용   12866  152784218

# %%
Final = pd.concat([GyeonGiHap2 , Hap])
Final = Final.sort_values('시군구')
Final
# Out:
#                년월     시구  시군구 계약구분 고객호수(호)    사용량(kWh)
# 30  201407-201412  울산광역시   남구  일반용   24824   379739662
# 30  201407-201412  울산광역시   남구   합계   21965  7563376657
# 31  201407-201412  울산광역시   동구  일반용    8053   119164151
# 31  201407-201412  울산광역시   동구   합계    9404   914087484
# 32  201407-201412  울산광역시   북구  일반용    7927   127472422
# 32  201407-201412  울산광역시   북구   합계    7735  1197380289
# 33  201407-201412  울산광역시  울주군  일반용   13912   172885018
# 33  201407-201412  울산광역시  울주군   합계   17131  5159918861
# 34  201407-201412  울산광역시   중구  일반용   12866   152784218
# 34  201407-201412  울산광역시   중구   합계   14649   331259440

# %%
# Final['일반용 전기의 비율'] = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']) // (Final['사용량(kWh)'].loc[Final['계약구분'] == '합계'])
# Final
ex = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']).tolist()


ex
# Out:
# [379739662, 119164151, 127472422, 172885018, 152784218]

# %%
ex_2 =(Final['사용량(kWh)'].loc[Final['계약구분'] == '합계']).tolist()
ex_2
# Out:
# [7563376657, 914087484, 1197380289, 5159918861, 331259440]

# %%
Rate = []
ilban = []
rae = 0
for i in range(len(ex)):
    rae = round(ex[i] / ex_2[i] *100 ,2)
    Rate.append(rae)
print(Rate)
# Out:
# [5.02, 13.04, 10.65, 3.35, 46.12]

# %%
Rate3 = pd.Series(Rate)
Rate3

# Final = pd.concat([Final , Rate3])
# Final
# Out:
# 0    5
# 1   13
# 2   11
# 3    3
# 4   46
# dtype: float64

# %%
for j in range(len(Rate)):
    ilban.append('일반용')
#print(Rate)

Rate2 = pd.DataFrame()
Rate2['시군구'] = pd.DataFrame(SIGUNGU)
Rate2['계약구분'] = pd.DataFrame(ilban)
Rate2['비율'] = pd.DataFrame(Rate)
Rate2
#print(Rate2.dtypes)
# Out:
#    시군구 계약구분  비율
# 0   남구  일반용   5
# 1   동구  일반용  13
# 2   북구  일반용  11
# 3  울주군  일반용   3
# 4   중구  일반용  46

# %%
Final = pd.merge(Final , Rate2, on=['시군구', '계약구분'] , how='left')

#Final.drop(['비율_y]' , axis = 1 , inplace = True)
#Final.rename(columns={'비율_y':'전체 계약종별 전력사용량 대비 일반용 사용량 비율'})
Final = Final.sort_values(['시군구' , '계약구분'])
Final
# Out:
#               년월     시구  시군구 계약구분 고객호수(호)    사용량(kWh)  비율
# 0  201407-201412  울산광역시   남구  일반용   24824   379739662   5
# 1  201407-201412  울산광역시   남구   합계   21965  7563376657 NaN
# 2  201407-201412  울산광역시   동구  일반용    8053   119164151  13
# 3  201407-201412  울산광역시   동구   합계    9404   914087484 NaN
# 4  201407-201412  울산광역시   북구  일반용    7927   127472422  11
# 5  201407-201412  울산광역시   북구   합계    7735  1197380289 NaN
# 6  201407-201412  울산광역시  울주군  일반용   13912   172885018   3
# 7  201407-201412  울산광역시  울주군   합계   17131  5159918861 NaN
# 8  201407-201412  울산광역시   중구  일반용   12866   152784218  46
# 9  201407-201412  울산광역시   중구   합계   14649   331259440 NaN

# %%
# Final['일반용 전기의 비율'] = Final.append(Rate)
# Final

# %% [markdown]
# ### 6. 날짜 체크!!!!!!!!!!!!!!!!!!!!1

# %%
Final.to_csv("{}_일반용_전력사용량_1407-12.csv".format(City) , mode = 'w' , encoding= 'cp949' , index =False) #파일명 수정

# %%
# Sigu = list(set(df_3['시군구'].tolist()))
#
# Sigu.sort()
#
# Sigu

# %%
# YearMonth = list(set(df_3['년월'].tolist()))
#
# YearMonth.sort()
# YearMonth

# %%
# Gayeak = list(set(df_3['계약구분'].tolist()))
#
# Gayeak.sort()
# Gayeak

# %%
# SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
# SEOUL.drop(['고객호수(호)' ,'전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
# #SEOUL.dtypes(['사용량(kWh)'])
# SEOUL

# %%
#SEOUL.to_csv("서울특별시_일반용_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
# print(SEOUL.dtypes)
# SEOUL = SEOUL.astype({'사용량(kWh)' : 'float'})

# %%
# SEOUL

# %%
# a = SEOUL['사용량(kWh)'].tolist()
# int_list = map(int, a)
# b=0
# for i in int_list:
#     b+=i
#
# print(b)
