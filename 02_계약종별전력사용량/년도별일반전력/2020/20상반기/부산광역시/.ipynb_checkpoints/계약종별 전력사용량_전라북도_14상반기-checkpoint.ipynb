# %%
import pandas as pd
import re

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ### 1. 꼭 read_csv 21상반기, 19하반기와 같이 맞추어 주세요!!! 또한 지역(전라북도, 남도) 맞추기!!!!!

# %%
df = pd.read_csv('부산광역시_계약종별_전력사용량_월별_20상반기.csv' , encoding='cp949')

df
#exchng=  pd.read_csv('지역별_전력거래량_20220803093050.csv' , encoding='cp949')
# Out:
#         계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0    시도 : 부산광역시, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1        기간 : 2020년 01 월 ~ 2020년 06월        NaN            NaN        NaN
# 2                                 년월         시구            시군구       계약구분
# 3                             202001      부산광역시  전체(시 / 군 / 구)        주택용
# 4                             202001      부산광역시  전체(시 / 군 / 구)        일반용
# ..                               ...        ...            ...        ...
# 811                           202006      부산광역시           해운대구        산업용
# 812                           202006      부산광역시           해운대구        심 야
# 813                           202006      부산광역시           해운대구        일반용
# 814                           202006      부산광역시           해운대구        주택용
# 815                           202006      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0          NaN           NaN              NaN            NaN
# 1          NaN           NaN              NaN            NaN
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     954,832   424,301,812   47,378,513,927          111.7
# 4     188,631   583,646,000   79,186,893,104          135.7
# ..         ...           ...              ...            ...
# 811       932    14,136,858    1,917,275,721          135.6
# 812       846     1,680,113      119,745,995           71.3
# 813    14,690    71,050,819    9,875,935,878            139
# 814    72,596    53,066,320    5,875,703,996          110.7
# 815    94,479   143,703,969   18,229,845,691          126.9
#
# [816 rows x 8 columns]

# %%
df = df.drop([0,1 , 46] , axis = 0)
#0,1 , 10은 지우는게 맞다
df
# Out:
#     계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 2                             년월         시구            시군구       계약구분
# 3                         202001      부산광역시  전체(시 / 군 / 구)        주택용
# 4                         202001      부산광역시  전체(시 / 군 / 구)        일반용
# 5                         202001      부산광역시  전체(시 / 군 / 구)        교육용
# 6                         202001      부산광역시  전체(시 / 군 / 구)        산업용
# ..                           ...        ...            ...        ...
# 811                       202006      부산광역시           해운대구        산업용
# 812                       202006      부산광역시           해운대구        심 야
# 813                       202006      부산광역시           해운대구        일반용
# 814                       202006      부산광역시           해운대구        주택용
# 815                       202006      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     954,832   424,301,812   47,378,513,927          111.7
# 4     188,631   583,646,000   79,186,893,104          135.7
# 5       1,166    41,640,286    4,511,943,330          108.4
# 6      24,955   719,582,496   89,317,169,959          124.1
# ..         ...           ...              ...            ...
# 811       932    14,136,858    1,917,275,721          135.6
# 812       846     1,680,113      119,745,995           71.3
# 813    14,690    71,050,819    9,875,935,878            139
# 814    72,596    53,066,320    5,875,703,996          110.7
# 815    94,479   143,703,969   18,229,845,691          126.9
#
# [813 rows x 8 columns]

# %%
a= df.loc[2].tolist()
a
df = df.drop([2] , axis = 0)

# %%
df.columns = a
df
# Out:
#          년월     시구            시군구 계약구분   고객호수(호)      사용량(kWh)  \
# 3    202001  부산광역시  전체(시 / 군 / 구)  주택용  954,832   424,301,812
# 4    202001  부산광역시  전체(시 / 군 / 구)  일반용  188,631   583,646,000
# 5    202001  부산광역시  전체(시 / 군 / 구)  교육용    1,166    41,640,286
# 6    202001  부산광역시  전체(시 / 군 / 구)  산업용   24,955   719,582,496
# 7    202001  부산광역시  전체(시 / 군 / 구)  농사용   11,614    11,821,145
# ..      ...    ...            ...  ...       ...           ...
# 811  202006  부산광역시           해운대구  산업용      932    14,136,858
# 812  202006  부산광역시           해운대구  심 야      846     1,680,113
# 813  202006  부산광역시           해운대구  일반용   14,690    71,050,819
# 814  202006  부산광역시           해운대구  주택용   72,596    53,066,320
# 815  202006  부산광역시           해운대구   합계   94,479   143,703,969
#
#              전기요금(원) 평균판매단가(원/kWh)
# 3    47,378,513,927         111.7
# 4    79,186,893,104         135.7
# 5     4,511,943,330         108.4
# 6    89,317,169,959         124.1
# 7       583,981,155          49.4
# ..               ...           ...
# 811   1,917,275,721         135.6
# 812     119,745,995          71.3
# 813   9,875,935,878           139
# 814   5,875,703,996         110.7
# 815  18,229,845,691         126.9
#
# [812 rows x 8 columns]

# %%
df_2 = df.loc[:45]
df_2
# Out:
#         년월     시구            시군구 계약구분    고객호수(호)        사용량(kWh)  \
# 3   202001  부산광역시  전체(시 / 군 / 구)  주택용   954,832     424,301,812
# 4   202001  부산광역시  전체(시 / 군 / 구)  일반용   188,631     583,646,000
# 5   202001  부산광역시  전체(시 / 군 / 구)  교육용     1,166      41,640,286
# 6   202001  부산광역시  전체(시 / 군 / 구)  산업용    24,955     719,582,496
# 7   202001  부산광역시  전체(시 / 군 / 구)  농사용    11,614      11,821,145
# 8   202001  부산광역시  전체(시 / 군 / 구)  가로등    85,965      16,720,596
# 9   202001  부산광역시  전체(시 / 군 / 구)  심 야    19,704      34,717,362
# 10  202002  부산광역시  전체(시 / 군 / 구)  주택용   954,418     428,231,976
# 11  202002  부산광역시  전체(시 / 군 / 구)  일반용   188,776     561,514,150
# 12  202002  부산광역시  전체(시 / 군 / 구)  교육용     1,165      39,167,653
# 13  202002  부산광역시  전체(시 / 군 / 구)  산업용    24,931     691,135,077
# 14  202002  부산광역시  전체(시 / 군 / 구)  농사용    11,626      11,335,643
# 15  202002  부산광역시  전체(시 / 군 / 구)  가로등    85,864      16,350,802
# 16  202002  부산광역시  전체(시 / 군 / 구)  심 야    19,624      34,481,945
# 17  202003  부산광역시  전체(시 / 군 / 구)  주택용   954,414     399,839,445
# 18  202003  부산광역시  전체(시 / 군 / 구)  일반용   188,669     482,456,750
# 19  202003  부산광역시  전체(시 / 군 / 구)  교육용     1,163      30,508,228
# 20  202003  부산광역시  전체(시 / 군 / 구)  산업용    24,921     705,078,344
# 21  202003  부산광역시  전체(시 / 군 / 구)  농사용    11,761       9,389,477
# 22  202003  부산광역시  전체(시 / 군 / 구)  가로등    85,851      15,240,683
# 23  202003  부산광역시  전체(시 / 군 / 구)  심 야    19,546      27,597,634
# 24  202004  부산광역시  전체(시 / 군 / 구)  주택용   954,636     406,705,461
# 25  202004  부산광역시  전체(시 / 군 / 구)  일반용   188,518     457,805,365
# 26  202004  부산광역시  전체(시 / 군 / 구)  교육용     1,158      26,349,211
# 27  202004  부산광역시  전체(시 / 군 / 구)  산업용    24,943     671,163,389
# 28  202004  부산광역시  전체(시 / 군 / 구)  농사용    11,693       8,314,114
# 29  202004  부산광역시  전체(시 / 군 / 구)  가로등    86,013      14,404,208
# 30  202004  부산광역시  전체(시 / 군 / 구)  심 야    19,457      22,327,746
# 31  202005  부산광역시  전체(시 / 군 / 구)  주택용   954,554     377,095,416
# 32  202005  부산광역시  전체(시 / 군 / 구)  일반용   188,426     451,785,856
# 33  202005  부산광역시  전체(시 / 군 / 구)  교육용     1,154      23,472,090
# 34  202005  부산광역시  전체(시 / 군 / 구)  산업용    24,916     619,863,162
# 35  202005  부산광역시  전체(시 / 군 / 구)  농사용    11,693       7,637,161
# 36  202005  부산광역시  전체(시 / 군 / 구)  가로등    86,058      13,596,846
# 37  202005  부산광역시  전체(시 / 군 / 구)  심 야    19,362      16,648,837
# 38  202006  부산광역시  전체(시 / 군 / 구)  주택용   954,489     383,410,345
# 39  202006  부산광역시  전체(시 / 군 / 구)  일반용   188,698     514,525,288
# 40  202006  부산광역시  전체(시 / 군 / 구)  교육용     1,148      29,564,414
# 41  202006  부산광역시  전체(시 / 군 / 구)  산업용    24,916     654,257,817
# 42  202006  부산광역시  전체(시 / 군 / 구)  농사용    11,739       7,810,979
# 43  202006  부산광역시  전체(시 / 군 / 구)  가로등    86,175      12,511,353
# 44  202006  부산광역시  전체(시 / 군 / 구)  심 야    19,274      12,936,063
# 45      합계     합계             합계   합계  7,718,616  10,016,942,625
#
#               전기요금(원) 평균판매단가(원/kWh)
# 3     47,378,513,927         111.7
# 4     79,186,893,104         135.7
# 5      4,511,943,330         108.4
# 6     89,317,169,959         124.1
# 7        583,981,155          49.4
# 8      1,772,246,018         106.0
# 9      2,637,552,686          76.0
# 10    48,077,251,133         112.3
# 11    77,300,130,438         137.7
# 12     4,358,899,082         111.3
# 13    87,763,899,493         127.0
# 14       562,757,605          49.6
# 15     1,778,287,348         108.8
# 16     2,617,266,710          75.9
# 17    42,688,780,338         106.8
# 18    62,360,261,570         129.3
# 19     3,349,327,229         109.8
# 20    75,288,068,097         106.8
# 21       480,207,015          51.1
# 22     1,672,743,477         109.8
# 23     1,858,331,268          67.3
# 24    43,776,660,943         107.6
# 25    54,946,459,176         120.0
# 26     2,557,470,845          97.1
# 27    70,041,124,241         104.4
# 28       436,836,496          52.5
# 29     1,630,861,819         113.2
# 30     1,255,816,306          56.2
# 31    38,541,555,350         102.2
# 32    54,512,305,489         120.7
# 33     2,358,401,124         100.5
# 34    65,920,663,386         106.3
# 35       400,587,842          52.5
# 36     1,574,311,266         115.8
# 37       973,121,265          58.4
# 38    39,529,199,916         103.1
# 39    70,733,864,451         137.5
# 40     3,502,375,499         118.5
# 41    84,092,618,050         128.5
# 42       406,167,025          52.0
# 43     1,496,725,593         119.6
# 44       817,611,909          63.2
# 45  1,175,049,248,973         117.3

# %%
GyeonGi  = df_2.loc[(df_2['계약구분'] == '일반용')]
#SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
GyeonGi
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\730399353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
#         년월     시구 계약구분   고객호수(호)      사용량(kWh)
# 4   202001  부산광역시  일반용  188,631   583,646,000
# 11  202002  부산광역시  일반용  188,776   561,514,150
# 18  202003  부산광역시  일반용  188,669   482,456,750
# 25  202004  부산광역시  일반용  188,518   457,805,365
# 32  202005  부산광역시  일반용  188,426   451,785,856
# 39  202006  부산광역시  일반용  188,698   514,525,288

# %%
#SEOUL1.to_csv("서울특별시_계약종별_전국_전력사용량_2022.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df_2.to_csv("서울특별시_계약종별_전국_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
df_3 = df.loc[48:]
df_3 = df_3.loc[(df_3['계약구분'] == '일반용')]
df_3 = df_3.sort_values(by=['시군구' , '년월'])
df_3.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   202001  부산광역시   강서구  일반용   9,936   40,060,840
# 181  202002  부산광역시   강서구  일반용   9,943   37,890,111
# 309  202003  부산광역시   강서구  일반용   9,978   34,671,622
# 437  202004  부산광역시   강서구  일반용   9,969   32,264,744
# 565  202005  부산광역시   강서구  일반용   9,994   31,956,305
# ..      ...    ...   ...  ...      ...          ...
# 301  202002  부산광역시  해운대구  일반용  14,680   71,906,088
# 429  202003  부산광역시  해운대구  일반용  14,671   61,721,937
# 557  202004  부산광역시  해운대구  일반용  14,668   58,823,992
# 685  202005  부산광역시  해운대구  일반용  14,662   61,568,236
# 813  202006  부산광역시  해운대구  일반용  14,690   71,050,819
#
# [96 rows x 6 columns]

# %%
a = df_3.loc[: , "시구"]
b = a[:1].tolist()
for i in b:
    City = i
City
# Out:
# '부산광역시'

# %%
SIGUNGU = list(set(df_3.loc[: , '시군구'].tolist()))
SIGUNGU.sort()
SIGUNGU
# Out:
# ['강서구',
#  '금정구',
#  '기장군',
#  '남구',
#  '동구',
#  '동래구',
#  '부산진구',
#  '북구',
#  '사상구',
#  '사하구',
#  '서구',
#  '수영구',
#  '연제구',
#  '영도구',
#  '중구',
#  '해운대구']

# %%
df_4 = df.loc[48:]
df_4 = df_4.loc[(df_4['계약구분'] == '합계')]
df_4 = df_4.sort_values(by=['시군구' , '년월'])
df_4.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_4
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 55   202001  부산광역시   강서구   합계  55,034   353,803,420
# 183  202002  부산광역시   강서구   합계  55,011   341,374,086
# 311  202003  부산광역시   강서구   합계  55,089   347,712,512
# 439  202004  부산광역시   강서구   합계  55,161   328,555,448
# 567  202005  부산광역시   강서구   합계  55,174   304,971,755
# ..      ...    ...   ...  ...      ...           ...
# 303  202002  부산광역시  해운대구   합계  94,506   153,988,253
# 431  202003  부산광역시  해운대구   합계  94,550   139,128,766
# 559  202004  부산광역시  해운대구   합계  94,543   136,697,076
# 687  202005  부산광역시  해운대구   합계  94,442   131,581,515
# 815  202006  부산광역시  해운대구   합계  94,479   143,703,969
#
# [96 rows x 6 columns]

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_4['사용량(kWh)'].loc[(df_4['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_4['고객호수(호)'].loc[(df_4['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//36) #6개월 치로 나눠야하나?!




print("{} 지역별 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# Out:
# [353803420, 341374086, 347712512, 328555448, 304971755, 324850053]
# [98999116, 96857789, 87182288, 84717673, 78832729, 83905103]
# [118731363, 112195199, 96152299, 91012453, 81946128, 88044311]
# [122507822, 120764951, 115251837, 111007860, 108469248, 111416192]
# [47257387, 46365403, 41827409, 39897386, 37471691, 40390955]
# [84577978, 83297656, 74096337, 72443951, 69111380, 74147528]
# [152925182, 148111123, 133467985, 127980495, 123663153, 134749299]
# [79688728, 78751133, 69739939, 69063630, 64899306, 69890440]
# [145712618, 140699629, 133720475, 127757734, 110776719, 120576670]
# [218958919, 213829859, 210752039, 205022278, 196020806, 204780129]
# [52346562, 49910756, 46396294, 43844128, 42627225, 46117022]
# [53960802, 53143584, 47302146, 46324658, 43648331, 46788377]
# [68785941, 67840809, 61257940, 59462038, 57004446, 62375354]
# [42021164, 41878905, 37506432, 36372627, 33172963, 34943077]
# [34018811, 33208111, 28615863, 26910059, 25901973, 28337780]
# [158133884, 153988253, 139128766, 136697076, 131581515, 143703969]
# 부산광역시 지역별 합계 :  [2001267274, 530494698, 588081753, 689417910, 253210231, 457674830, 820897237, 432033176, 779243845, 1249364030, 281241987, 291167898, 376726528, 225895168, 176992597, 863233463]
# 부산광역시 고객호수 평균:  [9187, 18820, 9344, 16608, 8870, 15527, 23077, 13008, 13848, 19505, 10208, 12631, 12018, 9651, 6348, 15748]

# %% [markdown]
# ### 2. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = df_4.copy()
Hap.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
Hap
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\4200931704.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 0           202001  부산광역시   강서구   합계  55,034   353,803,420
# 1           202002  부산광역시   강서구   합계  55,011   341,374,086
# 2           202003  부산광역시   강서구   합계  55,089   347,712,512
# 3           202004  부산광역시   강서구   합계  55,161   328,555,448
# 4           202005  부산광역시   강서구   합계  55,174   304,971,755
# ..             ...    ...   ...  ...      ...           ...
# 107  202001-202006  부산광역시   수영구   합계    12631     291167898
# 108  202001-202006  부산광역시   연제구   합계    12018     376726528
# 109  202001-202006  부산광역시   영도구   합계     9651     225895168
# 110  202001-202006  부산광역시    중구   합계     6348     176992597
# 111  202001-202006  부산광역시  해운대구   합계    15748     863233463
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 3. 날짜 변경!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = Hap.loc[Hap['년월'] == '202001-202006']
Hap
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   202001-202006  부산광역시   강서구   합계    9187  2001267274
# 97   202001-202006  부산광역시   금정구   합계   18820   530494698
# 98   202001-202006  부산광역시   기장군   합계    9344   588081753
# 99   202001-202006  부산광역시    남구   합계   16608   689417910
# 100  202001-202006  부산광역시    동구   합계    8870   253210231
# 101  202001-202006  부산광역시   동래구   합계   15527   457674830
# 102  202001-202006  부산광역시  부산진구   합계   23077   820897237
# 103  202001-202006  부산광역시    북구   합계   13008   432033176
# 104  202001-202006  부산광역시   사상구   합계   13848   779243845
# 105  202001-202006  부산광역시   사하구   합계   19505  1249364030
# 106  202001-202006  부산광역시    서구   합계   10208   281241987
# 107  202001-202006  부산광역시   수영구   합계   12631   291167898
# 108  202001-202006  부산광역시   연제구   합계   12018   376726528
# 109  202001-202006  부산광역시   영도구   합계    9651   225895168
# 110  202001-202006  부산광역시    중구   합계    6348   176992597
# 111  202001-202006  부산광역시  해운대구   합계   15748   863233463

# %%
# SIGUNGU = SIGUNGU[:1]
# SIGUNGU
#for i in SIGUNGU:
#print('{}'.format(i))
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
a = (df_3.columns).tolist()

a
# Out:
# ['년월', '시구', '시군구', '계약구분', '고객호수(호)', '사용량(kWh)']

# %%
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   202001  부산광역시   강서구  일반용   9,936   40,060,840
# 181  202002  부산광역시   강서구  일반용   9,943   37,890,111
# 309  202003  부산광역시   강서구  일반용   9,978   34,671,622
# 437  202004  부산광역시   강서구  일반용   9,969   32,264,744
# 565  202005  부산광역시   강서구  일반용   9,994   31,956,305
# ..      ...    ...   ...  ...      ...          ...
# 301  202002  부산광역시  해운대구  일반용  14,680   71,906,088
# 429  202003  부산광역시  해운대구  일반용  14,671   61,721,937
# 557  202004  부산광역시  해운대구  일반용  14,668   58,823,992
# 685  202005  부산광역시  해운대구  일반용  14,662   61,568,236
# 813  202006  부산광역시  해운대구  일반용  14,690   71,050,819
#
# [96 rows x 6 columns]

# %%
# GyeonGiHap = pd.DataFrame([] , columns = a)
# GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{가평군}')]
# GyeonGiHap

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_3['고객호수(호)'].loc[(df_3['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//6) #6개월 치로 나눠야하나?!




print("{} 지역별 일반용 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# GyeonGiHap['합계'] = sum
#
# GyeonGiHap
# Out:
# [40060840, 37890111, 34671622, 32264744, 31956305, 35719610]
# [35338016, 34160154, 29098452, 28027481, 27067302, 30548837]
# [30217449, 30517392, 23767572, 22720293, 22776231, 25193352]
# [35864136, 34754637, 30644225, 29399307, 28753121, 32578348]
# [26216484, 25339925, 22508327, 20674443, 19892779, 22740154]
# [37737838, 36350744, 30591944, 29167470, 28860727, 33320085]
# [73299741, 70311761, 60013171, 56454871, 56370256, 64991544]
# [31001937, 30129727, 25122143, 24052958, 23042524, 26474343]
# [37642875, 35849724, 31103102, 29624359, 28322565, 32229380]
# [38392529, 36988540, 31382414, 30457587, 29287901, 32975935]
# [20903807, 20043748, 18074506, 17014101, 16628137, 18772519]
# [26927261, 25814037, 22087786, 21136021, 20467737, 23161549]
# [33372309, 32344338, 28221889, 26379142, 26218122, 30506561]
# [14089019, 13699679, 11844289, 11434074, 10752897, 11860792]
# [26250566, 25413545, 21603371, 20174522, 19821016, 22401460]
# [76331193, 71906088, 61721937, 58823992, 61568236, 71050819]
# 부산광역시 지역별 일반용 합계 :  [212563232, 184240242, 155192289, 191993774, 137372112, 196028808, 381441344, 159823632, 194772005, 199484906, 111436818, 139594391, 177042361, 73680750, 135664480, 401402265]
# 부산광역시 고객호수 평균:  [9975, 15474, 8513, 12178, 7372, 15582, 23001, 10723, 13126, 14551, 6437, 10881, 11348, 6124, 8664, 14667]

# %%
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
# GyeonGiHap = df_3.copy()
# GyeonGiHap.reset_index(drop=True , inplace = True)
# GyeonGiHap.append({'년월' : '202107-202112'  , '시구' : '경기도' , '시군구' : '가평군' , '계약구분' : '일반용' , '사용량(kWh)' : sum}, ignore_index=True)

# %%
# a=[]
# for i in SIGUNGU:
#     a.append(i)
#
# print(a)

# %% [markdown]
# ### 4. 년월 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = df_3.copy()
GyeonGiHap2.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
GyeonGiHap2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_2748\1610350782.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202001-202006'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분 고객호수(호)     사용량(kWh)
# 0           202001  부산광역시   강서구  일반용  9,936   40,060,840
# 1           202002  부산광역시   강서구  일반용  9,943   37,890,111
# 2           202003  부산광역시   강서구  일반용  9,978   34,671,622
# 3           202004  부산광역시   강서구  일반용  9,969   32,264,744
# 4           202005  부산광역시   강서구  일반용  9,994   31,956,305
# ..             ...    ...   ...  ...     ...          ...
# 107  202001-202006  부산광역시   수영구  일반용   10881    139594391
# 108  202001-202006  부산광역시   연제구  일반용   11348    177042361
# 109  202001-202006  부산광역시   영도구  일반용    6124     73680750
# 110  202001-202006  부산광역시    중구  일반용    8664    135664480
# 111  202001-202006  부산광역시  해운대구  일반용   14667    401402265
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 5. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = GyeonGiHap2.loc[GyeonGiHap2['년월'] == '202001-202006']
GyeonGiHap2
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)   사용량(kWh)
# 96   202001-202006  부산광역시   강서구  일반용    9975  212563232
# 97   202001-202006  부산광역시   금정구  일반용   15474  184240242
# 98   202001-202006  부산광역시   기장군  일반용    8513  155192289
# 99   202001-202006  부산광역시    남구  일반용   12178  191993774
# 100  202001-202006  부산광역시    동구  일반용    7372  137372112
# 101  202001-202006  부산광역시   동래구  일반용   15582  196028808
# 102  202001-202006  부산광역시  부산진구  일반용   23001  381441344
# 103  202001-202006  부산광역시    북구  일반용   10723  159823632
# 104  202001-202006  부산광역시   사상구  일반용   13126  194772005
# 105  202001-202006  부산광역시   사하구  일반용   14551  199484906
# 106  202001-202006  부산광역시    서구  일반용    6437  111436818
# 107  202001-202006  부산광역시   수영구  일반용   10881  139594391
# 108  202001-202006  부산광역시   연제구  일반용   11348  177042361
# 109  202001-202006  부산광역시   영도구  일반용    6124   73680750
# 110  202001-202006  부산광역시    중구  일반용    8664  135664480
# 111  202001-202006  부산광역시  해운대구  일반용   14667  401402265

# %%
Final = pd.concat([GyeonGiHap2 , Hap])
Final = Final.sort_values('시군구')
Final
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   202001-202006  부산광역시   강서구  일반용    9975   212563232
# 96   202001-202006  부산광역시   강서구   합계    9187  2001267274
# 97   202001-202006  부산광역시   금정구   합계   18820   530494698
# 97   202001-202006  부산광역시   금정구  일반용   15474   184240242
# 98   202001-202006  부산광역시   기장군   합계    9344   588081753
# 98   202001-202006  부산광역시   기장군  일반용    8513   155192289
# 99   202001-202006  부산광역시    남구  일반용   12178   191993774
# 99   202001-202006  부산광역시    남구   합계   16608   689417910
# 100  202001-202006  부산광역시    동구  일반용    7372   137372112
# 100  202001-202006  부산광역시    동구   합계    8870   253210231
# 101  202001-202006  부산광역시   동래구  일반용   15582   196028808
# 101  202001-202006  부산광역시   동래구   합계   15527   457674830
# 102  202001-202006  부산광역시  부산진구  일반용   23001   381441344
# 102  202001-202006  부산광역시  부산진구   합계   23077   820897237
# 103  202001-202006  부산광역시    북구  일반용   10723   159823632
# 103  202001-202006  부산광역시    북구   합계   13008   432033176
# 104  202001-202006  부산광역시   사상구   합계   13848   779243845
# 104  202001-202006  부산광역시   사상구  일반용   13126   194772005
# 105  202001-202006  부산광역시   사하구   합계   19505  1249364030
# 105  202001-202006  부산광역시   사하구  일반용   14551   199484906
# 106  202001-202006  부산광역시    서구  일반용    6437   111436818
# 106  202001-202006  부산광역시    서구   합계   10208   281241987
# 107  202001-202006  부산광역시   수영구   합계   12631   291167898
# 107  202001-202006  부산광역시   수영구  일반용   10881   139594391
# 108  202001-202006  부산광역시   연제구   합계   12018   376726528
# 108  202001-202006  부산광역시   연제구  일반용   11348   177042361
# 109  202001-202006  부산광역시   영도구   합계    9651   225895168
# 109  202001-202006  부산광역시   영도구  일반용    6124    73680750
# 110  202001-202006  부산광역시    중구   합계    6348   176992597
# 110  202001-202006  부산광역시    중구  일반용    8664   135664480
# 111  202001-202006  부산광역시  해운대구  일반용   14667   401402265
# 111  202001-202006  부산광역시  해운대구   합계   15748   863233463

# %%
# Final['일반용 전기의 비율'] = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']) // (Final['사용량(kWh)'].loc[Final['계약구분'] == '합계'])
# Final
ex = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']).tolist()


ex
# Out:
# [212563232,
#  184240242,
#  155192289,
#  191993774,
#  137372112,
#  196028808,
#  381441344,
#  159823632,
#  194772005,
#  199484906,
#  111436818,
#  139594391,
#  177042361,
#  73680750,
#  135664480,
#  401402265]

# %%
ex_2 =(Final['사용량(kWh)'].loc[Final['계약구분'] == '합계']).tolist()
ex_2
# Out:
# [2001267274,
#  530494698,
#  588081753,
#  689417910,
#  253210231,
#  457674830,
#  820897237,
#  432033176,
#  779243845,
#  1249364030,
#  281241987,
#  291167898,
#  376726528,
#  225895168,
#  176992597,
#  863233463]

# %%
Rate = []
ilban = []
rae = 0
for i in range(len(ex)):
    rae = round(ex[i] / ex_2[i] *100 ,2)
    Rate.append(rae)
print(Rate)
# Out:
# [10.62, 34.73, 26.39, 27.85, 54.25, 42.83, 46.47, 36.99, 25.0, 15.97, 39.62, 47.94, 46.99, 32.62, 76.65, 46.5]

# %%
Rate3 = pd.Series(Rate)
Rate3

# Final = pd.concat([Final , Rate3])
# Final
# Out:
# 0    11
# 1    35
# 2    26
# 3    28
# 4    54
# 5    43
# 6    46
# 7    37
# 8    25
# 9    16
# 10   40
# 11   48
# 12   47
# 13   33
# 14   77
# 15   46
# dtype: float64

# %%
for j in range(len(Rate)):
    ilban.append('일반용')
#print(Rate)

Rate2 = pd.DataFrame()
Rate2['시군구'] = pd.DataFrame(SIGUNGU)
Rate2['계약구분'] = pd.DataFrame(ilban)
Rate2['비율'] = pd.DataFrame(Rate)
Rate2
#print(Rate2.dtypes)
# Out:
#      시군구 계약구분  비율
# 0    강서구  일반용  11
# 1    금정구  일반용  35
# 2    기장군  일반용  26
# 3     남구  일반용  28
# 4     동구  일반용  54
# 5    동래구  일반용  43
# 6   부산진구  일반용  46
# 7     북구  일반용  37
# 8    사상구  일반용  25
# 9    사하구  일반용  16
# 10    서구  일반용  40
# 11   수영구  일반용  48
# 12   연제구  일반용  47
# 13   영도구  일반용  33
# 14    중구  일반용  77
# 15  해운대구  일반용  46

# %%
Final = pd.merge(Final , Rate2, on=['시군구', '계약구분'] , how='left')

#Final.drop(['비율_y]' , axis = 1 , inplace = True)
#Final.rename(columns={'비율_y':'전체 계약종별 전력사용량 대비 일반용 사용량 비율'})
Final = Final.sort_values(['시군구' , '계약구분'])
Final
# Out:
#                년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)  비율
# 0   202001-202006  부산광역시   강서구  일반용    9975   212563232  11
# 1   202001-202006  부산광역시   강서구   합계    9187  2001267274 NaN
# 3   202001-202006  부산광역시   금정구  일반용   15474   184240242  35
# 2   202001-202006  부산광역시   금정구   합계   18820   530494698 NaN
# 5   202001-202006  부산광역시   기장군  일반용    8513   155192289  26
# 4   202001-202006  부산광역시   기장군   합계    9344   588081753 NaN
# 6   202001-202006  부산광역시    남구  일반용   12178   191993774  28
# 7   202001-202006  부산광역시    남구   합계   16608   689417910 NaN
# 8   202001-202006  부산광역시    동구  일반용    7372   137372112  54
# 9   202001-202006  부산광역시    동구   합계    8870   253210231 NaN
# 10  202001-202006  부산광역시   동래구  일반용   15582   196028808  43
# 11  202001-202006  부산광역시   동래구   합계   15527   457674830 NaN
# 12  202001-202006  부산광역시  부산진구  일반용   23001   381441344  46
# 13  202001-202006  부산광역시  부산진구   합계   23077   820897237 NaN
# 14  202001-202006  부산광역시    북구  일반용   10723   159823632  37
# 15  202001-202006  부산광역시    북구   합계   13008   432033176 NaN
# 17  202001-202006  부산광역시   사상구  일반용   13126   194772005  25
# 16  202001-202006  부산광역시   사상구   합계   13848   779243845 NaN
# 19  202001-202006  부산광역시   사하구  일반용   14551   199484906  16
# 18  202001-202006  부산광역시   사하구   합계   19505  1249364030 NaN
# 20  202001-202006  부산광역시    서구  일반용    6437   111436818  40
# 21  202001-202006  부산광역시    서구   합계   10208   281241987 NaN
# 23  202001-202006  부산광역시   수영구  일반용   10881   139594391  48
# 22  202001-202006  부산광역시   수영구   합계   12631   291167898 NaN
# 25  202001-202006  부산광역시   연제구  일반용   11348   177042361  47
# 24  202001-202006  부산광역시   연제구   합계   12018   376726528 NaN
# 27  202001-202006  부산광역시   영도구  일반용    6124    73680750  33
# 26  202001-202006  부산광역시   영도구   합계    9651   225895168 NaN
# 29  202001-202006  부산광역시    중구  일반용    8664   135664480  77
# 28  202001-202006  부산광역시    중구   합계    6348   176992597 NaN
# 30  202001-202006  부산광역시  해운대구  일반용   14667   401402265  46
# 31  202001-202006  부산광역시  해운대구   합계   15748   863233463 NaN

# %%
# Final['일반용 전기의 비율'] = Final.append(Rate)
# Final

# %% [markdown]
# ### 6. 날짜 체크!!!!!!!!!!!!!!!!!!!!1

# %%
Final.to_csv("{}_일반용_전력사용량_2001-06.csv".format(City) , mode = 'w' , encoding= 'cp949' , index =False) #파일명 수정

# %%
# Sigu = list(set(df_3['시군구'].tolist()))
#
# Sigu.sort()
#
# Sigu

# %%
# YearMonth = list(set(df_3['년월'].tolist()))
#
# YearMonth.sort()
# YearMonth

# %%
# Gayeak = list(set(df_3['계약구분'].tolist()))
#
# Gayeak.sort()
# Gayeak

# %%
# SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
# SEOUL.drop(['고객호수(호)' ,'전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
# #SEOUL.dtypes(['사용량(kWh)'])
# SEOUL

# %%
#SEOUL.to_csv("서울특별시_일반용_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
# print(SEOUL.dtypes)
# SEOUL = SEOUL.astype({'사용량(kWh)' : 'float'})

# %%
# SEOUL

# %%
# a = SEOUL['사용량(kWh)'].tolist()
# int_list = map(int, a)
# b=0
# for i in int_list:
#     b+=i
#
# print(b)
