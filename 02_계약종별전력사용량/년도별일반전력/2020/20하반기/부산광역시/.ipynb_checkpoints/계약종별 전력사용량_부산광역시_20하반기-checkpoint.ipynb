# %%
import pandas as pd
import re

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ### 1. 꼭 read_csv 21상반기, 19하반기와 같이 맞추어 주세요!!! 또한 지역(전라북도, 남도) 맞추기!!!!!

# %%
df = pd.read_csv('부산광역시_계약종별_전력사용량_월별_20하반기.csv' , encoding='cp949')

df
#exchng=  pd.read_csv('지역별_전력거래량_20220803093050.csv' , encoding='cp949')
# Out:
#         계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0    시도 : 부산광역시, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1        기간 : 2020년 07 월 ~ 2020년 12월        NaN            NaN        NaN
# 2                                 년월         시구            시군구       계약구분
# 3                             202007      부산광역시  전체(시 / 군 / 구)        주택용
# 4                             202007      부산광역시  전체(시 / 군 / 구)        일반용
# ..                               ...        ...            ...        ...
# 811                           202012      부산광역시           해운대구        산업용
# 812                           202012      부산광역시           해운대구        심 야
# 813                           202012      부산광역시           해운대구        일반용
# 814                           202012      부산광역시           해운대구        주택용
# 815                           202012      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0          NaN           NaN              NaN            NaN
# 1          NaN           NaN              NaN            NaN
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     954,489   392,057,995   38,126,664,774           97.2
# 4     189,018   553,644,907   82,929,352,782          149.8
# ..         ...           ...              ...            ...
# 811       921    19,961,816    2,432,897,910          121.9
# 812       830     1,535,547      122,405,525           79.7
# 813    14,805    69,715,187    9,829,355,060            141
# 814    72,592    54,234,671    6,082,761,144          112.2
# 815    94,660   150,206,341   18,991,677,673          126.4
#
# [816 rows x 8 columns]

# %%
df = df.drop([0,1 , 46] , axis = 0)
#0,1 , 10은 지우는게 맞다
df
# Out:
#     계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 2                             년월         시구            시군구       계약구분
# 3                         202007      부산광역시  전체(시 / 군 / 구)        주택용
# 4                         202007      부산광역시  전체(시 / 군 / 구)        일반용
# 5                         202007      부산광역시  전체(시 / 군 / 구)        교육용
# 6                         202007      부산광역시  전체(시 / 군 / 구)        산업용
# ..                           ...        ...            ...        ...
# 811                       202012      부산광역시           해운대구        산업용
# 812                       202012      부산광역시           해운대구        심 야
# 813                       202012      부산광역시           해운대구        일반용
# 814                       202012      부산광역시           해운대구        주택용
# 815                       202012      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     954,489   392,057,995   38,126,664,774           97.2
# 4     189,018   553,644,907   82,929,352,782          149.8
# 5       1,147    35,853,329    4,200,618,087          117.2
# 6      24,929   687,295,397   90,750,563,738          132.0
# ..         ...           ...              ...            ...
# 811       921    19,961,816    2,432,897,910          121.9
# 812       830     1,535,547      122,405,525           79.7
# 813    14,805    69,715,187    9,829,355,060            141
# 814    72,592    54,234,671    6,082,761,144          112.2
# 815    94,660   150,206,341   18,991,677,673          126.4
#
# [813 rows x 8 columns]

# %%
a= df.loc[2].tolist()
a
df = df.drop([2] , axis = 0)

# %%
df.columns = a
df
# Out:
#          년월     시구            시군구 계약구분   고객호수(호)      사용량(kWh)  \
# 3    202007  부산광역시  전체(시 / 군 / 구)  주택용  954,489   392,057,995
# 4    202007  부산광역시  전체(시 / 군 / 구)  일반용  189,018   553,644,907
# 5    202007  부산광역시  전체(시 / 군 / 구)  교육용    1,147    35,853,329
# 6    202007  부산광역시  전체(시 / 군 / 구)  산업용   24,929   687,295,397
# 7    202007  부산광역시  전체(시 / 군 / 구)  농사용   11,770     8,671,096
# ..      ...    ...            ...  ...       ...           ...
# 811  202012  부산광역시           해운대구  산업용      921    19,961,816
# 812  202012  부산광역시           해운대구  심 야      830     1,535,547
# 813  202012  부산광역시           해운대구  일반용   14,805    69,715,187
# 814  202012  부산광역시           해운대구  주택용   72,592    54,234,671
# 815  202012  부산광역시           해운대구   합계   94,660   150,206,341
#
#              전기요금(원) 평균판매단가(원/kWh)
# 3    38,126,664,774          97.2
# 4    82,929,352,782         149.8
# 5     4,200,618,087         117.2
# 6    90,750,563,738         132.0
# 7       419,864,943          48.4
# ..               ...           ...
# 811   2,432,897,910         121.9
# 812     122,405,525          79.7
# 813   9,829,355,060           141
# 814   6,082,761,144         112.2
# 815  18,991,677,673         126.4
#
# [812 rows x 8 columns]

# %%
df_2 = df.loc[:45]
df_2
# Out:
#         년월     시구            시군구 계약구분    고객호수(호)        사용량(kWh)  \
# 3   202007  부산광역시  전체(시 / 군 / 구)  주택용   954,489     392,057,995
# 4   202007  부산광역시  전체(시 / 군 / 구)  일반용   189,018     553,644,907
# 5   202007  부산광역시  전체(시 / 군 / 구)  교육용     1,147      35,853,329
# 6   202007  부산광역시  전체(시 / 군 / 구)  산업용    24,929     687,295,397
# 7   202007  부산광역시  전체(시 / 군 / 구)  농사용    11,770       8,671,096
# 8   202007  부산광역시  전체(시 / 군 / 구)  가로등    86,316      12,087,065
# 9   202007  부산광역시  전체(시 / 군 / 구)  심 야    19,198      11,928,097
# 10  202008  부산광역시  전체(시 / 군 / 구)  주택용   954,022     490,479,776
# 11  202008  부산광역시  전체(시 / 군 / 구)  일반용   189,087     635,890,460
# 12  202008  부산광역시  전체(시 / 군 / 구)  교육용     1,146      38,292,855
# 13  202008  부산광역시  전체(시 / 군 / 구)  산업용    24,918     679,953,527
# 14  202008  부산광역시  전체(시 / 군 / 구)  농사용    11,789      12,495,051
# 15  202008  부산광역시  전체(시 / 군 / 구)  가로등    87,332      12,476,345
# 16  202008  부산광역시  전체(시 / 군 / 구)  심 야    19,116      14,197,607
# 17  202009  부산광역시  전체(시 / 군 / 구)  주택용   953,844     530,814,021
# 18  202009  부산광역시  전체(시 / 군 / 구)  일반용   189,287     603,202,408
# 19  202009  부산광역시  전체(시 / 군 / 구)  교육용     1,144      37,397,025
# 20  202009  부산광역시  전체(시 / 군 / 구)  산업용    24,908     739,565,840
# 21  202009  부산광역시  전체(시 / 군 / 구)  농사용    11,821      10,668,594
# 22  202009  부산광역시  전체(시 / 군 / 구)  가로등    86,667      13,085,227
# 23  202009  부산광역시  전체(시 / 군 / 구)  심 야    19,024       9,533,462
# 24  202010  부산광역시  전체(시 / 군 / 구)  주택용   954,165     377,866,875
# 25  202010  부산광역시  전체(시 / 군 / 구)  일반용   189,126     464,770,112
# 26  202010  부산광역시  전체(시 / 군 / 구)  교육용     1,139      26,997,569
# 27  202010  부산광역시  전체(시 / 군 / 구)  산업용    24,906     656,080,784
# 28  202010  부산광역시  전체(시 / 군 / 구)  농사용    11,859       6,901,662
# 29  202010  부산광역시  전체(시 / 군 / 구)  가로등    86,886      13,852,953
# 30  202010  부산광역시  전체(시 / 군 / 구)  심 야    18,895       8,853,327
# 31  202011  부산광역시  전체(시 / 군 / 구)  주택용   954,594     388,320,023
# 32  202011  부산광역시  전체(시 / 군 / 구)  일반용   189,136     470,681,027
# 33  202011  부산광역시  전체(시 / 군 / 구)  교육용     1,141      31,569,855
# 34  202011  부산광역시  전체(시 / 군 / 구)  산업용    24,886     695,186,852
# 35  202011  부산광역시  전체(시 / 군 / 구)  농사용    12,049       7,796,551
# 36  202011  부산광역시  전체(시 / 군 / 구)  가로등    86,718      14,817,960
# 37  202011  부산광역시  전체(시 / 군 / 구)  심 야    18,817      15,508,162
# 38  202012  부산광역시  전체(시 / 군 / 구)  주택용   954,561     410,999,941
# 39  202012  부산광역시  전체(시 / 군 / 구)  일반용   189,575     522,616,894
# 40  202012  부산광역시  전체(시 / 군 / 구)  교육용     1,141      42,048,668
# 41  202012  부산광역시  전체(시 / 군 / 구)  산업용    24,853     751,671,947
# 42  202012  부산광역시  전체(시 / 군 / 구)  농사용    12,016      10,433,827
# 43  202012  부산광역시  전체(시 / 군 / 구)  가로등    86,888      15,623,472
# 44  202012  부산광역시  전체(시 / 군 / 구)  심 야    18,732      24,837,974
# 45      합계     합계             합계   합계  7,723,055  10,487,026,519
#
#               전기요금(원) 평균판매단가(원/kWh)
# 3     38,126,664,774          97.2
# 4     82,929,352,782         149.8
# 5      4,200,618,087         117.2
# 6     90,750,563,738         132.0
# 7        419,864,943          48.4
# 8      1,446,246,629         119.7
# 9        785,471,581          65.9
# 10    51,290,786,905         104.6
# 11    91,146,414,703         143.3
# 12     4,310,448,860         112.6
# 13    88,583,488,748         130.3
# 14       521,432,990          41.7
# 15     1,453,433,322         116.5
# 16       992,475,218          69.9
# 17    63,042,644,114         118.8
# 18    76,342,106,398         126.6
# 19     3,937,679,957         105.3
# 20    78,694,717,369         106.4
# 21       484,090,888          45.4
# 22     1,494,276,690         114.2
# 23       632,685,864          66.4
# 24    38,179,427,148         101.0
# 25    55,178,464,395         118.7
# 26     2,505,938,680          92.8
# 27    68,366,959,344         104.2
# 28       374,130,558          54.2
# 29     1,524,340,264         110.0
# 30       549,007,367          62.0
# 31    40,108,653,831         103.3
# 32    63,494,572,770         134.9
# 33     3,293,501,458         104.3
# 34    84,941,174,873         122.2
# 35       416,112,911          53.4
# 36     1,597,105,512         107.8
# 37     1,030,608,012          66.5
# 38    44,366,650,901         107.9
# 39    74,296,813,772         142.2
# 40     4,492,412,009         106.8
# 41    89,935,090,527         119.6
# 42       532,560,144          51.0
# 43     1,655,079,844         105.9
# 44     1,882,568,644          75.8
# 45  1,260,306,637,524         120.2

# %%
GyeonGi  = df_2.loc[(df_2['계약구분'] == '일반용')]
#SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
GyeonGi
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\730399353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
#         년월     시구 계약구분   고객호수(호)      사용량(kWh)
# 4   202007  부산광역시  일반용  189,018   553,644,907
# 11  202008  부산광역시  일반용  189,087   635,890,460
# 18  202009  부산광역시  일반용  189,287   603,202,408
# 25  202010  부산광역시  일반용  189,126   464,770,112
# 32  202011  부산광역시  일반용  189,136   470,681,027
# 39  202012  부산광역시  일반용  189,575   522,616,894

# %%
#SEOUL1.to_csv("서울특별시_계약종별_전국_전력사용량_2022.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df_2.to_csv("서울특별시_계약종별_전국_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
df_3 = df.loc[48:]
df_3 = df_3.loc[(df_3['계약구분'] == '일반용')]
df_3 = df_3.sort_values(by=['시군구' , '년월'])
df_3.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   202007  부산광역시   강서구  일반용  10,086   38,703,954
# 181  202008  부산광역시   강서구  일반용  10,116   43,436,314
# 309  202009  부산광역시   강서구  일반용  10,162   41,471,762
# 437  202010  부산광역시   강서구  일반용  10,208   33,925,991
# 565  202011  부산광역시   강서구  일반용  10,269   35,613,183
# ..      ...    ...   ...  ...      ...          ...
# 301  202008  부산광역시  해운대구  일반용  14,742   90,318,900
# 429  202009  부산광역시  해운대구  일반용  14,758   79,006,895
# 557  202010  부산광역시  해운대구  일반용  14,745   64,070,398
# 685  202011  부산광역시  해운대구  일반용  14,754   63,744,160
# 813  202012  부산광역시  해운대구  일반용  14,805   69,715,187
#
# [96 rows x 6 columns]

# %%
a = df_3.loc[: , "시구"]
b = a[:1].tolist()
for i in b:
    City = i
City
# Out:
# '부산광역시'

# %%
SIGUNGU = list(set(df_3.loc[: , '시군구'].tolist()))
SIGUNGU.sort()
SIGUNGU
# Out:
# ['강서구',
#  '금정구',
#  '기장군',
#  '남구',
#  '동구',
#  '동래구',
#  '부산진구',
#  '북구',
#  '사상구',
#  '사하구',
#  '서구',
#  '수영구',
#  '연제구',
#  '영도구',
#  '중구',
#  '해운대구']

# %%
df_4 = df.loc[48:]
df_4 = df_4.loc[(df_4['계약구분'] == '합계')]
df_4 = df_4.sort_values(by=['시군구' , '년월'])
df_4.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_4
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 55   202007  부산광역시   강서구   합계  55,348   340,499,481
# 183  202008  부산광역시   강서구   합계  55,379   346,819,931
# 311  202009  부산광역시   강서구   합계  55,495   358,262,235
# 439  202010  부산광역시   강서구   합계  55,571   320,275,240
# 567  202011  부산광역시   강서구   합계  55,760   341,636,855
# ..      ...    ...   ...  ...      ...           ...
# 303  202008  부산광역시  해운대구   합계  94,486   181,086,484
# 431  202009  부산광역시  해운대구   합계  94,575   176,748,516
# 559  202010  부산광역시  해운대구   합계  94,586   139,128,617
# 687  202011  부산광역시  해운대구   합계  94,644   140,347,989
# 815  202012  부산광역시  해운대구   합계  94,660   150,206,341
#
# [96 rows x 6 columns]

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_4['사용량(kWh)'].loc[(df_4['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_4['고객호수(호)'].loc[(df_4['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//36) #6개월 치로 나눠야하나?!




print("{} 지역별 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# Out:
# [340499481, 346819931, 358262235, 320275240, 341636855, 358672502]
# [87562822, 99389452, 102722794, 79249193, 83202578, 91707035]
# [97171254, 109315972, 141076296, 94781588, 92733160, 134764042]
# [116600003, 133383433, 134681151, 111243349, 112731710, 120562553]
# [43119654, 48924087, 49081725, 37701021, 38573108, 43491091]
# [77839241, 90211689, 93784396, 69510040, 71489792, 77698616]
# [143187143, 166875899, 162318014, 124838189, 126282918, 140765678]
# [72616000, 85393047, 84095156, 64810131, 67995263, 73471300]
# [123313160, 133231702, 140920174, 112854965, 126285964, 140334910]
# [213035375, 217316774, 226240354, 192575200, 210223761, 212975964]
# [50835387, 57389647, 57101298, 46373580, 46451747, 50321760]
# [49293062, 60047892, 62406740, 45529629, 46066412, 49918899]
# [65271379, 76709423, 77388400, 56908061, 59042226, 64988504]
# [37048757, 41566630, 41761433, 32827431, 34559308, 39248728]
# [30844215, 36123559, 35677895, 26717048, 26257639, 29104800]
# [153300953, 181086484, 176748516, 139128617, 140347989, 150206341]
# 부산광역시 지역별 합계 :  [2066166244, 543833874, 669842312, 729202199, 260890686, 480533774, 864267841, 448380897, 776940875, 1272367428, 308473419, 313262634, 400307993, 227012287, 184725156, 940818900]
# 부산광역시 고객호수 평균:  [9262, 18752, 9437, 16567, 8878, 15564, 23005, 12986, 13904, 19452, 10191, 12689, 12052, 9644, 6377, 15761]

# %% [markdown]
# ### 2. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = df_4.copy()
Hap.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
Hap
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\98075701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 0           202007  부산광역시   강서구   합계  55,348   340,499,481
# 1           202008  부산광역시   강서구   합계  55,379   346,819,931
# 2           202009  부산광역시   강서구   합계  55,495   358,262,235
# 3           202010  부산광역시   강서구   합계  55,571   320,275,240
# 4           202011  부산광역시   강서구   합계  55,760   341,636,855
# ..             ...    ...   ...  ...      ...           ...
# 107  202007-202012  부산광역시   수영구   합계    12689     313262634
# 108  202007-202012  부산광역시   연제구   합계    12052     400307993
# 109  202007-202012  부산광역시   영도구   합계     9644     227012287
# 110  202007-202012  부산광역시    중구   합계     6377     184725156
# 111  202007-202012  부산광역시  해운대구   합계    15761     940818900
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 3. 날짜 변경!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = Hap.loc[Hap['년월'] == '202007-202012']
Hap
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   202007-202012  부산광역시   강서구   합계    9262  2066166244
# 97   202007-202012  부산광역시   금정구   합계   18752   543833874
# 98   202007-202012  부산광역시   기장군   합계    9437   669842312
# 99   202007-202012  부산광역시    남구   합계   16567   729202199
# 100  202007-202012  부산광역시    동구   합계    8878   260890686
# 101  202007-202012  부산광역시   동래구   합계   15564   480533774
# 102  202007-202012  부산광역시  부산진구   합계   23005   864267841
# 103  202007-202012  부산광역시    북구   합계   12986   448380897
# 104  202007-202012  부산광역시   사상구   합계   13904   776940875
# 105  202007-202012  부산광역시   사하구   합계   19452  1272367428
# 106  202007-202012  부산광역시    서구   합계   10191   308473419
# 107  202007-202012  부산광역시   수영구   합계   12689   313262634
# 108  202007-202012  부산광역시   연제구   합계   12052   400307993
# 109  202007-202012  부산광역시   영도구   합계    9644   227012287
# 110  202007-202012  부산광역시    중구   합계    6377   184725156
# 111  202007-202012  부산광역시  해운대구   합계   15761   940818900

# %%
# SIGUNGU = SIGUNGU[:1]
# SIGUNGU
#for i in SIGUNGU:
#print('{}'.format(i))
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
a = (df_3.columns).tolist()

a
# Out:
# ['년월', '시구', '시군구', '계약구분', '고객호수(호)', '사용량(kWh)']

# %%
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   202007  부산광역시   강서구  일반용  10,086   38,703,954
# 181  202008  부산광역시   강서구  일반용  10,116   43,436,314
# 309  202009  부산광역시   강서구  일반용  10,162   41,471,762
# 437  202010  부산광역시   강서구  일반용  10,208   33,925,991
# 565  202011  부산광역시   강서구  일반용  10,269   35,613,183
# ..      ...    ...   ...  ...      ...          ...
# 301  202008  부산광역시  해운대구  일반용  14,742   90,318,900
# 429  202009  부산광역시  해운대구  일반용  14,758   79,006,895
# 557  202010  부산광역시  해운대구  일반용  14,745   64,070,398
# 685  202011  부산광역시  해운대구  일반용  14,754   63,744,160
# 813  202012  부산광역시  해운대구  일반용  14,805   69,715,187
#
# [96 rows x 6 columns]

# %%
# GyeonGiHap = pd.DataFrame([] , columns = a)
# GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{가평군}')]
# GyeonGiHap

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_3['고객호수(호)'].loc[(df_3['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//6) #6개월 치로 나눠야하나?!




print("{} 지역별 일반용 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# GyeonGiHap['합계'] = sum
#
# GyeonGiHap
# Out:
# [38703954, 43436314, 41471762, 33925991, 35613183, 39238819]
# [32128437, 36837433, 35793920, 26955098, 27947608, 30812016]
# [26734876, 31181097, 29361202, 24009470, 24276044, 27867028]
# [34658584, 39228149, 37796372, 29092990, 29586784, 33325175]
# [24654989, 27797041, 26771347, 20112189, 20432149, 23500639]
# [35939317, 41075250, 39728273, 29477905, 29996615, 32917307]
# [70417293, 80672892, 75941798, 57448208, 56041440, 62815689]
# [28188677, 32354199, 31071692, 23156225, 23949715, 26398266]
# [34239911, 39287971, 37415129, 28211749, 29686700, 33544885]
# [35525762, 40453167, 40108002, 30631839, 31304540, 33663573]
# [20204793, 23205770, 21978144, 17176162, 17283523, 19313153]
# [25090714, 29680479, 29379842, 22198057, 22066170, 23974100]
# [32590355, 37073646, 35376968, 26296173, 27127851, 30754498]
# [12613210, 14541636, 14379853, 11116907, 11505171, 12617186]
# [24681330, 28746516, 27621209, 20890751, 20119374, 22159373]
# [77272705, 90318900, 79006895, 64070398, 63744160, 69715187]
# 부산광역시 지역별 일반용 합계 :  [232390023, 190474512, 163429717, 203688054, 143268354, 209134667, 403337320, 165118774, 202386345, 211686883, 119161545, 152389362, 189219491, 76773963, 144218553, 444128245]
# 부산광역시 고객호수 평균:  [10197, 15477, 8750, 12221, 7369, 15589, 22961, 10735, 13111, 14530, 6472, 11015, 11376, 6165, 8477, 14753]

# %%
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
# GyeonGiHap = df_3.copy()
# GyeonGiHap.reset_index(drop=True , inplace = True)
# GyeonGiHap.append({'년월' : '202107-202112'  , '시구' : '경기도' , '시군구' : '가평군' , '계약구분' : '일반용' , '사용량(kWh)' : sum}, ignore_index=True)

# %%
# a=[]
# for i in SIGUNGU:
#     a.append(i)
#
# print(a)

# %% [markdown]
# ### 4. 년월 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = df_3.copy()
GyeonGiHap2.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
GyeonGiHap2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\3863292304.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'202007-202012'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 0           202007  부산광역시   강서구  일반용  10,086   38,703,954
# 1           202008  부산광역시   강서구  일반용  10,116   43,436,314
# 2           202009  부산광역시   강서구  일반용  10,162   41,471,762
# 3           202010  부산광역시   강서구  일반용  10,208   33,925,991
# 4           202011  부산광역시   강서구  일반용  10,269   35,613,183
# ..             ...    ...   ...  ...      ...          ...
# 107  202007-202012  부산광역시   수영구  일반용    11015    152389362
# 108  202007-202012  부산광역시   연제구  일반용    11376    189219491
# 109  202007-202012  부산광역시   영도구  일반용     6165     76773963
# 110  202007-202012  부산광역시    중구  일반용     8477    144218553
# 111  202007-202012  부산광역시  해운대구  일반용    14753    444128245
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 5. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = GyeonGiHap2.loc[GyeonGiHap2['년월'] == '202007-202012']
GyeonGiHap2
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)   사용량(kWh)
# 96   202007-202012  부산광역시   강서구  일반용   10197  232390023
# 97   202007-202012  부산광역시   금정구  일반용   15477  190474512
# 98   202007-202012  부산광역시   기장군  일반용    8750  163429717
# 99   202007-202012  부산광역시    남구  일반용   12221  203688054
# 100  202007-202012  부산광역시    동구  일반용    7369  143268354
# 101  202007-202012  부산광역시   동래구  일반용   15589  209134667
# 102  202007-202012  부산광역시  부산진구  일반용   22961  403337320
# 103  202007-202012  부산광역시    북구  일반용   10735  165118774
# 104  202007-202012  부산광역시   사상구  일반용   13111  202386345
# 105  202007-202012  부산광역시   사하구  일반용   14530  211686883
# 106  202007-202012  부산광역시    서구  일반용    6472  119161545
# 107  202007-202012  부산광역시   수영구  일반용   11015  152389362
# 108  202007-202012  부산광역시   연제구  일반용   11376  189219491
# 109  202007-202012  부산광역시   영도구  일반용    6165   76773963
# 110  202007-202012  부산광역시    중구  일반용    8477  144218553
# 111  202007-202012  부산광역시  해운대구  일반용   14753  444128245

# %%
Final = pd.concat([GyeonGiHap2 , Hap])
Final = Final.sort_values('시군구')
Final
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   202007-202012  부산광역시   강서구  일반용   10197   232390023
# 96   202007-202012  부산광역시   강서구   합계    9262  2066166244
# 97   202007-202012  부산광역시   금정구   합계   18752   543833874
# 97   202007-202012  부산광역시   금정구  일반용   15477   190474512
# 98   202007-202012  부산광역시   기장군   합계    9437   669842312
# 98   202007-202012  부산광역시   기장군  일반용    8750   163429717
# 99   202007-202012  부산광역시    남구  일반용   12221   203688054
# 99   202007-202012  부산광역시    남구   합계   16567   729202199
# 100  202007-202012  부산광역시    동구  일반용    7369   143268354
# 100  202007-202012  부산광역시    동구   합계    8878   260890686
# 101  202007-202012  부산광역시   동래구  일반용   15589   209134667
# 101  202007-202012  부산광역시   동래구   합계   15564   480533774
# 102  202007-202012  부산광역시  부산진구  일반용   22961   403337320
# 102  202007-202012  부산광역시  부산진구   합계   23005   864267841
# 103  202007-202012  부산광역시    북구  일반용   10735   165118774
# 103  202007-202012  부산광역시    북구   합계   12986   448380897
# 104  202007-202012  부산광역시   사상구   합계   13904   776940875
# 104  202007-202012  부산광역시   사상구  일반용   13111   202386345
# 105  202007-202012  부산광역시   사하구   합계   19452  1272367428
# 105  202007-202012  부산광역시   사하구  일반용   14530   211686883
# 106  202007-202012  부산광역시    서구  일반용    6472   119161545
# 106  202007-202012  부산광역시    서구   합계   10191   308473419
# 107  202007-202012  부산광역시   수영구   합계   12689   313262634
# 107  202007-202012  부산광역시   수영구  일반용   11015   152389362
# 108  202007-202012  부산광역시   연제구   합계   12052   400307993
# 108  202007-202012  부산광역시   연제구  일반용   11376   189219491
# 109  202007-202012  부산광역시   영도구   합계    9644   227012287
# 109  202007-202012  부산광역시   영도구  일반용    6165    76773963
# 110  202007-202012  부산광역시    중구   합계    6377   184725156
# 110  202007-202012  부산광역시    중구  일반용    8477   144218553
# 111  202007-202012  부산광역시  해운대구  일반용   14753   444128245
# 111  202007-202012  부산광역시  해운대구   합계   15761   940818900

# %%
# Final['일반용 전기의 비율'] = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']) // (Final['사용량(kWh)'].loc[Final['계약구분'] == '합계'])
# Final
ex = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']).tolist()


ex
# Out:
# [232390023,
#  190474512,
#  163429717,
#  203688054,
#  143268354,
#  209134667,
#  403337320,
#  165118774,
#  202386345,
#  211686883,
#  119161545,
#  152389362,
#  189219491,
#  76773963,
#  144218553,
#  444128245]

# %%
ex_2 =(Final['사용량(kWh)'].loc[Final['계약구분'] == '합계']).tolist()
ex_2
# Out:
# [2066166244,
#  543833874,
#  669842312,
#  729202199,
#  260890686,
#  480533774,
#  864267841,
#  448380897,
#  776940875,
#  1272367428,
#  308473419,
#  313262634,
#  400307993,
#  227012287,
#  184725156,
#  940818900]

# %%
Rate = []
ilban = []
rae = 0
for i in range(len(ex)):
    rae = round(ex[i] / ex_2[i] *100 ,2)
    Rate.append(rae)
print(Rate)
# Out:
# [11.25, 35.02, 24.4, 27.93, 54.92, 43.52, 46.67, 36.83, 26.05, 16.64, 38.63, 48.65, 47.27, 33.82, 78.07, 47.21]

# %%
Rate3 = pd.Series(Rate)
Rate3

# Final = pd.concat([Final , Rate3])
# Final
# Out:
# 0    11
# 1    35
# 2    24
# 3    28
# 4    55
# 5    44
# 6    47
# 7    37
# 8    26
# 9    17
# 10   39
# 11   49
# 12   47
# 13   34
# 14   78
# 15   47
# dtype: float64

# %%
for j in range(len(Rate)):
    ilban.append('일반용')
#print(Rate)

Rate2 = pd.DataFrame()
Rate2['시군구'] = pd.DataFrame(SIGUNGU)
Rate2['계약구분'] = pd.DataFrame(ilban)
Rate2['비율'] = pd.DataFrame(Rate)
Rate2
#print(Rate2.dtypes)
# Out:
#      시군구 계약구분  비율
# 0    강서구  일반용  11
# 1    금정구  일반용  35
# 2    기장군  일반용  24
# 3     남구  일반용  28
# 4     동구  일반용  55
# 5    동래구  일반용  44
# 6   부산진구  일반용  47
# 7     북구  일반용  37
# 8    사상구  일반용  26
# 9    사하구  일반용  17
# 10    서구  일반용  39
# 11   수영구  일반용  49
# 12   연제구  일반용  47
# 13   영도구  일반용  34
# 14    중구  일반용  78
# 15  해운대구  일반용  47

# %%
Final = pd.merge(Final , Rate2, on=['시군구', '계약구분'] , how='left')

#Final.drop(['비율_y]' , axis = 1 , inplace = True)
#Final.rename(columns={'비율_y':'전체 계약종별 전력사용량 대비 일반용 사용량 비율'})
Final = Final.sort_values(['시군구' , '계약구분'])
Final
# Out:
#                년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)  비율
# 0   202007-202012  부산광역시   강서구  일반용   10197   232390023  11
# 1   202007-202012  부산광역시   강서구   합계    9262  2066166244 NaN
# 3   202007-202012  부산광역시   금정구  일반용   15477   190474512  35
# 2   202007-202012  부산광역시   금정구   합계   18752   543833874 NaN
# 5   202007-202012  부산광역시   기장군  일반용    8750   163429717  24
# 4   202007-202012  부산광역시   기장군   합계    9437   669842312 NaN
# 6   202007-202012  부산광역시    남구  일반용   12221   203688054  28
# 7   202007-202012  부산광역시    남구   합계   16567   729202199 NaN
# 8   202007-202012  부산광역시    동구  일반용    7369   143268354  55
# 9   202007-202012  부산광역시    동구   합계    8878   260890686 NaN
# 10  202007-202012  부산광역시   동래구  일반용   15589   209134667  44
# 11  202007-202012  부산광역시   동래구   합계   15564   480533774 NaN
# 12  202007-202012  부산광역시  부산진구  일반용   22961   403337320  47
# 13  202007-202012  부산광역시  부산진구   합계   23005   864267841 NaN
# 14  202007-202012  부산광역시    북구  일반용   10735   165118774  37
# 15  202007-202012  부산광역시    북구   합계   12986   448380897 NaN
# 17  202007-202012  부산광역시   사상구  일반용   13111   202386345  26
# 16  202007-202012  부산광역시   사상구   합계   13904   776940875 NaN
# 19  202007-202012  부산광역시   사하구  일반용   14530   211686883  17
# 18  202007-202012  부산광역시   사하구   합계   19452  1272367428 NaN
# 20  202007-202012  부산광역시    서구  일반용    6472   119161545  39
# 21  202007-202012  부산광역시    서구   합계   10191   308473419 NaN
# 23  202007-202012  부산광역시   수영구  일반용   11015   152389362  49
# 22  202007-202012  부산광역시   수영구   합계   12689   313262634 NaN
# 25  202007-202012  부산광역시   연제구  일반용   11376   189219491  47
# 24  202007-202012  부산광역시   연제구   합계   12052   400307993 NaN
# 27  202007-202012  부산광역시   영도구  일반용    6165    76773963  34
# 26  202007-202012  부산광역시   영도구   합계    9644   227012287 NaN
# 29  202007-202012  부산광역시    중구  일반용    8477   144218553  78
# 28  202007-202012  부산광역시    중구   합계    6377   184725156 NaN
# 30  202007-202012  부산광역시  해운대구  일반용   14753   444128245  47
# 31  202007-202012  부산광역시  해운대구   합계   15761   940818900 NaN

# %%
# Final['일반용 전기의 비율'] = Final.append(Rate)
# Final

# %% [markdown]
# ### 6. 날짜 체크!!!!!!!!!!!!!!!!!!!!1

# %%
Final.to_csv("{}_일반용_전력사용량_2007-12.csv".format(City) , mode = 'w' , encoding= 'cp949' , index =False) #파일명 수정

# %%
# Sigu = list(set(df_3['시군구'].tolist()))
#
# Sigu.sort()
#
# Sigu

# %%
# YearMonth = list(set(df_3['년월'].tolist()))
#
# YearMonth.sort()
# YearMonth

# %%
# Gayeak = list(set(df_3['계약구분'].tolist()))
#
# Gayeak.sort()
# Gayeak

# %%
# SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
# SEOUL.drop(['고객호수(호)' ,'전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
# #SEOUL.dtypes(['사용량(kWh)'])
# SEOUL

# %%
#SEOUL.to_csv("서울특별시_일반용_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
# print(SEOUL.dtypes)
# SEOUL = SEOUL.astype({'사용량(kWh)' : 'float'})

# %%
# SEOUL

# %%
# a = SEOUL['사용량(kWh)'].tolist()
# int_list = map(int, a)
# b=0
# for i in int_list:
#     b+=i
#
# print(b)
