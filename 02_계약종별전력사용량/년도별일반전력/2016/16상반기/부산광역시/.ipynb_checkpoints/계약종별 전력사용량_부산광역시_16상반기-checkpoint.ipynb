# %%
import pandas as pd
import re

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ### 1. 꼭 read_csv 21상반기, 19하반기와 같이 맞추어 주세요!!! 또한 지역(전라북도, 남도) 맞추기!!!!!

# %%
df = pd.read_csv('부산광역시_계약종별_전력사용량_월별_16상반기.csv' , encoding='cp949')

df
#exchng=  pd.read_csv('지역별_전력거래량_20220803093050.csv' , encoding='cp949')
# Out:
#         계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0    시도 : 부산광역시, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1        기간 : 2016년 01 월 ~ 2016년 06월        NaN            NaN        NaN
# 2                                 년월         시구            시군구       계약구분
# 3                             201601      부산광역시  전체(시 / 군 / 구)        주택용
# 4                             201601      부산광역시  전체(시 / 군 / 구)        일반용
# ..                               ...        ...            ...        ...
# 811                           201606      부산광역시           해운대구        산업용
# 812                           201606      부산광역시           해운대구        심 야
# 813                           201606      부산광역시           해운대구        일반용
# 814                           201606      부산광역시           해운대구        주택용
# 815                           201606      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0          NaN           NaN              NaN            NaN
# 1          NaN           NaN              NaN            NaN
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     941,032   411,703,888   55,326,849,348          134.4
# 4     183,887   563,686,085   76,320,743,709          135.4
# ..         ...           ...              ...            ...
# 811       978    21,943,136    2,571,463,022          117.2
# 812     1,039     2,834,271      185,067,494           65.3
# 813    13,799    71,032,667    9,695,257,219          136.5
# 814    71,725    49,864,307    6,249,259,528          125.3
# 815    92,561   149,937,719   19,226,728,485          128.2
#
# [816 rows x 8 columns]

# %%
df = df.drop([0,1 , 46] , axis = 0)
#0,1 , 10은 지우는게 맞다
df
# Out:
#     계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 2                             년월         시구            시군구       계약구분
# 3                         201601      부산광역시  전체(시 / 군 / 구)        주택용
# 4                         201601      부산광역시  전체(시 / 군 / 구)        일반용
# 5                         201601      부산광역시  전체(시 / 군 / 구)        교육용
# 6                         201601      부산광역시  전체(시 / 군 / 구)        산업용
# ..                           ...        ...            ...        ...
# 811                       201606      부산광역시           해운대구        산업용
# 812                       201606      부산광역시           해운대구        심 야
# 813                       201606      부산광역시           해운대구        일반용
# 814                       201606      부산광역시           해운대구        주택용
# 815                       201606      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     941,032   411,703,888   55,326,849,348          134.4
# 4     183,887   563,686,085   76,320,743,709          135.4
# 5       1,164    41,869,044    4,599,121,343          109.8
# 6      24,925   712,403,026   88,647,446,269          124.4
# ..         ...           ...              ...            ...
# 811       978    21,943,136    2,571,463,022          117.2
# 812     1,039     2,834,271      185,067,494           65.3
# 813    13,799    71,032,667    9,695,257,219          136.5
# 814    71,725    49,864,307    6,249,259,528          125.3
# 815    92,561   149,937,719   19,226,728,485          128.2
#
# [813 rows x 8 columns]

# %%
a= df.loc[2].tolist()
a
df = df.drop([2] , axis = 0)

# %%
df.columns = a
df
# Out:
#          년월     시구            시군구 계약구분   고객호수(호)      사용량(kWh)  \
# 3    201601  부산광역시  전체(시 / 군 / 구)  주택용  941,032   411,703,888
# 4    201601  부산광역시  전체(시 / 군 / 구)  일반용  183,887   563,686,085
# 5    201601  부산광역시  전체(시 / 군 / 구)  교육용    1,164    41,869,044
# 6    201601  부산광역시  전체(시 / 군 / 구)  산업용   24,925   712,403,026
# 7    201601  부산광역시  전체(시 / 군 / 구)  농사용   10,078    12,337,035
# ..      ...    ...            ...  ...       ...           ...
# 811  201606  부산광역시           해운대구  산업용      978    21,943,136
# 812  201606  부산광역시           해운대구  심 야    1,039     2,834,271
# 813  201606  부산광역시           해운대구  일반용   13,799    71,032,667
# 814  201606  부산광역시           해운대구  주택용   71,725    49,864,307
# 815  201606  부산광역시           해운대구   합계   92,561   149,937,719
#
#              전기요금(원) 평균판매단가(원/kWh)
# 3    55,326,849,348         134.4
# 4    76,320,743,709         135.4
# 5     4,599,121,343         109.8
# 6    88,647,446,269         124.4
# 7       595,402,741          48.3
# ..               ...           ...
# 811   2,571,463,022         117.2
# 812     185,067,494          65.3
# 813   9,695,257,219         136.5
# 814   6,249,259,528         125.3
# 815  19,226,728,485         128.2
#
# [812 rows x 8 columns]

# %%
df_2 = df.loc[:45]
df_2
# Out:
#         년월     시구            시군구 계약구분    고객호수(호)        사용량(kWh)  \
# 3   201601  부산광역시  전체(시 / 군 / 구)  주택용   941,032     411,703,888
# 4   201601  부산광역시  전체(시 / 군 / 구)  일반용   183,887     563,686,085
# 5   201601  부산광역시  전체(시 / 군 / 구)  교육용     1,164      41,869,044
# 6   201601  부산광역시  전체(시 / 군 / 구)  산업용    24,925     712,403,026
# 7   201601  부산광역시  전체(시 / 군 / 구)  농사용    10,078      12,337,035
# 8   201601  부산광역시  전체(시 / 군 / 구)  가로등    78,931      17,043,576
# 9   201601  부산광역시  전체(시 / 군 / 구)  심 야    24,282      51,650,110
# 10  201602  부산광역시  전체(시 / 군 / 구)  주택용   941,293     422,664,878
# 11  201602  부산광역시  전체(시 / 군 / 구)  일반용   184,120     578,216,563
# 12  201602  부산광역시  전체(시 / 군 / 구)  교육용     1,170      43,775,690
# 13  201602  부산광역시  전체(시 / 군 / 구)  산업용    24,943     670,760,772
# 14  201602  부산광역시  전체(시 / 군 / 구)  농사용    10,091      13,506,964
# 15  201602  부산광역시  전체(시 / 군 / 구)  가로등    79,051      16,592,059
# 16  201602  부산광역시  전체(시 / 군 / 구)  심 야    24,184      56,979,001
# 17  201603  부산광역시  전체(시 / 군 / 구)  주택용   941,289     375,764,330
# 18  201603  부산광역시  전체(시 / 군 / 구)  일반용   184,026     512,619,799
# 19  201603  부산광역시  전체(시 / 군 / 구)  교육용     1,167      41,955,354
# 20  201603  부산광역시  전체(시 / 군 / 구)  산업용    24,941     716,525,984
# 21  201603  부산광역시  전체(시 / 군 / 구)  농사용    10,225      10,495,513
# 22  201603  부산광역시  전체(시 / 군 / 구)  가로등    79,201      15,639,477
# 23  201603  부산광역시  전체(시 / 군 / 구)  심 야    24,039      44,795,111
# 24  201604  부산광역시  전체(시 / 군 / 구)  주택용   942,017     378,566,463
# 25  201604  부산광역시  전체(시 / 군 / 구)  일반용   184,034     482,804,862
# 26  201604  부산광역시  전체(시 / 군 / 구)  교육용     1,169      38,028,982
# 27  201604  부산광역시  전체(시 / 군 / 구)  산업용    24,967     689,895,774
# 28  201604  부산광역시  전체(시 / 군 / 구)  농사용    10,163       8,444,140
# 29  201604  부산광역시  전체(시 / 군 / 구)  가로등    79,244      14,657,980
# 30  201604  부산광역시  전체(시 / 군 / 구)  심 야    23,915      34,707,472
# 31  201605  부산광역시  전체(시 / 군 / 구)  주택용   942,568     348,518,306
# 32  201605  부산광역시  전체(시 / 군 / 구)  일반용   183,911     460,677,237
# 33  201605  부산광역시  전체(시 / 군 / 구)  교육용     1,168      30,294,033
# 34  201605  부산광역시  전체(시 / 군 / 구)  산업용    24,978     674,478,492
# 35  201605  부산광역시  전체(시 / 군 / 구)  농사용    10,165       7,444,177
# 36  201605  부산광역시  전체(시 / 군 / 구)  가로등    79,531      13,822,469
# 37  201605  부산광역시  전체(시 / 군 / 구)  심 야    23,779      23,350,431
# 38  201606  부산광역시  전체(시 / 군 / 구)  주택용   943,354     351,776,323
# 39  201606  부산광역시  전체(시 / 군 / 구)  일반용   184,008     496,315,973
# 40  201606  부산광역시  전체(시 / 군 / 구)  교육용     1,166      34,025,044
# 41  201606  부산광역시  전체(시 / 군 / 구)  산업용    25,013     684,422,027
# 42  201606  부산광역시  전체(시 / 군 / 구)  농사용    10,217       6,989,391
# 43  201606  부산광역시  전체(시 / 군 / 구)  가로등    79,750      12,870,390
# 44  201606  부산광역시  전체(시 / 군 / 구)  심 야    23,654      17,874,563
# 45      합계     합계             합계   합계  7,592,810  10,140,948,788
#
#               전기요금(원) 평균판매단가(원/kWh)
# 3     55,326,849,348         134.4
# 4     76,320,743,709         135.4
# 5      4,599,121,343         109.8
# 6     88,647,446,269         124.4
# 7        595,402,741          48.3
# 8      1,796,141,730         105.4
# 9      3,949,949,982          76.5
# 10    58,210,284,563         137.7
# 11    77,635,062,732         134.3
# 12     4,896,758,971         111.9
# 13    84,704,402,965         126.3
# 14       642,426,427          47.6
# 15     1,792,068,365         108.0
# 16     4,354,288,662          76.4
# 17    46,001,425,455         122.4
# 18    63,557,207,666         124.0
# 19     4,344,212,707         103.5
# 20    76,077,824,926         106.2
# 21       511,266,038          48.7
# 22     1,707,528,363         109.2
# 23     3,028,324,581          67.6
# 24    46,289,110,189         122.3
# 25    55,728,642,699         115.4
# 26     3,738,676,296          98.3
# 27    71,120,573,499         103.1
# 28       432,765,117          51.3
# 29     1,656,642,446         113.0
# 30     1,949,322,532          56.2
# 31    39,782,044,079         114.1
# 32    54,125,698,071         117.5
# 33     3,254,020,182         107.4
# 34    70,635,594,005         104.7
# 35       375,475,538          50.4
# 36     1,595,595,185         115.4
# 37     1,374,143,261          58.8
# 38    40,822,468,362         116.0
# 39    67,421,343,245         135.8
# 40     4,140,488,296         121.7
# 41    86,616,796,645         126.6
# 42       362,503,521          51.9
# 43     1,530,934,990         119.0
# 44     1,113,218,325          62.3
# 45  1,212,764,794,026         119.6

# %%
GyeonGi  = df_2.loc[(df_2['계약구분'] == '일반용')]
#SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
GyeonGi
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\730399353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
#         년월     시구 계약구분   고객호수(호)      사용량(kWh)
# 4   201601  부산광역시  일반용  183,887   563,686,085
# 11  201602  부산광역시  일반용  184,120   578,216,563
# 18  201603  부산광역시  일반용  184,026   512,619,799
# 25  201604  부산광역시  일반용  184,034   482,804,862
# 32  201605  부산광역시  일반용  183,911   460,677,237
# 39  201606  부산광역시  일반용  184,008   496,315,973

# %%
#SEOUL1.to_csv("서울특별시_계약종별_전국_전력사용량_2022.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df_2.to_csv("서울특별시_계약종별_전국_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
df_3 = df.loc[48:]
df_3 = df_3.loc[(df_3['계약구분'] == '일반용')]
df_3 = df_3.sort_values(by=['시군구' , '년월'])
df_3.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201601  부산광역시   강서구  일반용   8,181   26,111,602
# 181  201602  부산광역시   강서구  일반용   8,256   26,434,409
# 309  201603  부산광역시   강서구  일반용   8,287   24,585,322
# 437  201604  부산광역시   강서구  일반용   8,338   23,245,625
# 565  201605  부산광역시   강서구  일반용   8,402   22,259,847
# ..      ...    ...   ...  ...      ...          ...
# 301  201602  부산광역시  해운대구  일반용  13,783   75,191,374
# 429  201603  부산광역시  해운대구  일반용  13,784   69,254,139
# 557  201604  부산광역시  해운대구  일반용  13,803   64,688,622
# 685  201605  부산광역시  해운대구  일반용  13,776   64,690,410
# 813  201606  부산광역시  해운대구  일반용  13,799   71,032,667
#
# [96 rows x 6 columns]

# %%
a = df_3.loc[: , "시구"]
b = a[:1].tolist()
for i in b:
    City = i
City
# Out:
# '부산광역시'

# %%
SIGUNGU = list(set(df_3.loc[: , '시군구'].tolist()))
SIGUNGU.sort()
SIGUNGU
# Out:
# ['강서구',
#  '금정구',
#  '기장군',
#  '남구',
#  '동구',
#  '동래구',
#  '부산진구',
#  '북구',
#  '사상구',
#  '사하구',
#  '서구',
#  '수영구',
#  '연제구',
#  '영도구',
#  '중구',
#  '해운대구']

# %%
df_4 = df.loc[48:]
df_4 = df_4.loc[(df_4['계약구분'] == '합계')]
df_4 = df_4.sort_values(by=['시군구' , '년월'])
df_4.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_4
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 55   201601  부산광역시   강서구   합계  46,218   296,268,466
# 183  201602  부산광역시   강서구   합계  46,486   292,127,980
# 311  201603  부산광역시   강서구   합계  46,559   302,199,525
# 439  201604  부산광역시   강서구   합계  46,771   288,694,332
# 567  201605  부산광역시   강서구   합계  46,941   279,477,013
# ..      ...    ...   ...  ...      ...           ...
# 303  201602  부산광역시  해운대구   합계  92,538   160,609,514
# 431  201603  부산광역시  해운대구   합계  92,554   150,122,596
# 559  201604  부산광역시  해운대구   합계  92,651   144,660,104
# 687  201605  부산광역시  해운대구   합계  92,542   140,780,997
# 815  201606  부산광역시  해운대구   합계  92,561   149,937,719
#
# [96 rows x 6 columns]

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_4['사용량(kWh)'].loc[(df_4['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_4['고객호수(호)'].loc[(df_4['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//36) #6개월 치로 나눠야하나?!




print("{} 지역별 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# Out:
# [296268466, 292127980, 302199525, 288694332, 279477013, 283945022]
# [100102664, 101609073, 91368220, 88621919, 79817058, 84017305]
# [95022308, 92472231, 96543674, 88634940, 85000622, 77745276]
# [122293201, 121903354, 117336528, 112866724, 108015918, 110911999]
# [48280864, 49505104, 44185062, 41017381, 37867753, 39950410]
# [84637035, 87409267, 76978788, 73418393, 67575833, 70642940]
# [150472549, 153363227, 137676260, 131221069, 123041018, 131018041]
# [83815589, 83609079, 73615402, 71543004, 65963947, 69811121]
# [164832199, 164771502, 157393383, 151588521, 139052576, 145407075]
# [245577372, 233291962, 236511383, 231112994, 226067370, 224207686]
# [53260034, 50748121, 47442482, 46446622, 42862607, 45456831]
# [52604467, 54837622, 47471544, 45570440, 41616329, 43582444]
# [69203516, 71635320, 63606961, 60644376, 56324492, 59962407]
# [44839780, 45737319, 41334140, 39063439, 35379039, 35611200]
# [37324138, 38865252, 34009620, 32001415, 29742573, 32066235]
# [162158582, 160609514, 150122596, 144660104, 140780997, 149937719]
# 부산광역시 지역별 합계 :  [1742712338, 545536239, 535419051, 693327724, 260806574, 460662256, 826792164, 448358142, 923045256, 1396768767, 286216697, 285682846, 381377072, 241964917, 204009233, 908269512]
# 부산광역시 고객호수 평균:  [7779, 17922, 8296, 17050, 8926, 15860, 23988, 12783, 13491, 18992, 10339, 12000, 12036, 9811, 6203, 15428]

# %% [markdown]
# ### 2. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = df_4.copy()
Hap.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
Hap
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\4171278030.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 0           201601  부산광역시   강서구   합계  46,218   296,268,466
# 1           201602  부산광역시   강서구   합계  46,486   292,127,980
# 2           201603  부산광역시   강서구   합계  46,559   302,199,525
# 3           201604  부산광역시   강서구   합계  46,771   288,694,332
# 4           201605  부산광역시   강서구   합계  46,941   279,477,013
# ..             ...    ...   ...  ...      ...           ...
# 107  201601-201606  부산광역시   수영구   합계    12000     285682846
# 108  201601-201606  부산광역시   연제구   합계    12036     381377072
# 109  201601-201606  부산광역시   영도구   합계     9811     241964917
# 110  201601-201606  부산광역시    중구   합계     6203     204009233
# 111  201601-201606  부산광역시  해운대구   합계    15428     908269512
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 3. 날짜 변경!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = Hap.loc[Hap['년월'] == '201601-201606']
Hap
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   201601-201606  부산광역시   강서구   합계    7779  1742712338
# 97   201601-201606  부산광역시   금정구   합계   17922   545536239
# 98   201601-201606  부산광역시   기장군   합계    8296   535419051
# 99   201601-201606  부산광역시    남구   합계   17050   693327724
# 100  201601-201606  부산광역시    동구   합계    8926   260806574
# 101  201601-201606  부산광역시   동래구   합계   15860   460662256
# 102  201601-201606  부산광역시  부산진구   합계   23988   826792164
# 103  201601-201606  부산광역시    북구   합계   12783   448358142
# 104  201601-201606  부산광역시   사상구   합계   13491   923045256
# 105  201601-201606  부산광역시   사하구   합계   18992  1396768767
# 106  201601-201606  부산광역시    서구   합계   10339   286216697
# 107  201601-201606  부산광역시   수영구   합계   12000   285682846
# 108  201601-201606  부산광역시   연제구   합계   12036   381377072
# 109  201601-201606  부산광역시   영도구   합계    9811   241964917
# 110  201601-201606  부산광역시    중구   합계    6203   204009233
# 111  201601-201606  부산광역시  해운대구   합계   15428   908269512

# %%
# SIGUNGU = SIGUNGU[:1]
# SIGUNGU
#for i in SIGUNGU:
#print('{}'.format(i))
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
a = (df_3.columns).tolist()

a
# Out:
# ['년월', '시구', '시군구', '계약구분', '고객호수(호)', '사용량(kWh)']

# %%
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201601  부산광역시   강서구  일반용   8,181   26,111,602
# 181  201602  부산광역시   강서구  일반용   8,256   26,434,409
# 309  201603  부산광역시   강서구  일반용   8,287   24,585,322
# 437  201604  부산광역시   강서구  일반용   8,338   23,245,625
# 565  201605  부산광역시   강서구  일반용   8,402   22,259,847
# ..      ...    ...   ...  ...      ...          ...
# 301  201602  부산광역시  해운대구  일반용  13,783   75,191,374
# 429  201603  부산광역시  해운대구  일반용  13,784   69,254,139
# 557  201604  부산광역시  해운대구  일반용  13,803   64,688,622
# 685  201605  부산광역시  해운대구  일반용  13,776   64,690,410
# 813  201606  부산광역시  해운대구  일반용  13,799   71,032,667
#
# [96 rows x 6 columns]

# %%
# GyeonGiHap = pd.DataFrame([] , columns = a)
# GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{가평군}')]
# GyeonGiHap

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_3['고객호수(호)'].loc[(df_3['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//6) #6개월 치로 나눠야하나?!




print("{} 지역별 일반용 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# GyeonGiHap['합계'] = sum
#
# GyeonGiHap
# Out:
# [26111602, 26434409, 24585322, 23245625, 22259847, 24003670]
# [35368084, 36893252, 32139798, 30020162, 27975231, 30733087]
# [25699271, 26624019, 26683633, 27641344, 28593987, 19076444]
# [33815110, 34933506, 30690688, 29269856, 27447074, 30842348]
# [26753079, 27576657, 24385730, 22340268, 21150893, 23206638]
# [38505559, 39793674, 34451637, 32035778, 30232691, 33467212]
# [72027073, 74766800, 65812311, 61722039, 59064820, 65819239]
# [31911127, 32652904, 27973396, 26235359, 24362317, 27251699]
# [38140658, 39033140, 33515576, 31414292, 29282590, 32627674]
# [37238941, 38457974, 32955370, 31062227, 28734036, 31618865]
# [20238783, 20447512, 18335581, 17257294, 16259897, 17639394]
# [25856172, 26954496, 23193833, 21676669, 20074253, 22054266]
# [34158024, 35374568, 30849074, 28583448, 27154791, 30361622]
# [12692633, 13333333, 11618658, 11084778, 10039830, 10694362]
# [28777193, 29748945, 26175053, 24527101, 23354570, 25886786]
# [76392776, 75191374, 69254139, 64688622, 64690410, 71032667]
# 부산광역시 지역별 일반용 합계 :  [146640475, 193129614, 154318698, 186998582, 145413265, 208486551, 399212282, 170386802, 204013930, 200067413, 110178461, 139809689, 186481527, 69463594, 158469648, 421249988]
# 부산광역시 고객호수 평균:  [8315, 15213, 7451, 11786, 7568, 15638, 22992, 10591, 13328, 14250, 6660, 10348, 11008, 6002, 9057, 13784]

# %%
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
# GyeonGiHap = df_3.copy()
# GyeonGiHap.reset_index(drop=True , inplace = True)
# GyeonGiHap.append({'년월' : '202107-202112'  , '시구' : '경기도' , '시군구' : '가평군' , '계약구분' : '일반용' , '사용량(kWh)' : sum}, ignore_index=True)

# %%
# a=[]
# for i in SIGUNGU:
#     a.append(i)
#
# print(a)

# %% [markdown]
# ### 4. 년월 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = df_3.copy()
GyeonGiHap2.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
GyeonGiHap2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\2328676442.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201601-201606'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분 고객호수(호)     사용량(kWh)
# 0           201601  부산광역시   강서구  일반용  8,181   26,111,602
# 1           201602  부산광역시   강서구  일반용  8,256   26,434,409
# 2           201603  부산광역시   강서구  일반용  8,287   24,585,322
# 3           201604  부산광역시   강서구  일반용  8,338   23,245,625
# 4           201605  부산광역시   강서구  일반용  8,402   22,259,847
# ..             ...    ...   ...  ...     ...          ...
# 107  201601-201606  부산광역시   수영구  일반용   10348    139809689
# 108  201601-201606  부산광역시   연제구  일반용   11008    186481527
# 109  201601-201606  부산광역시   영도구  일반용    6002     69463594
# 110  201601-201606  부산광역시    중구  일반용    9057    158469648
# 111  201601-201606  부산광역시  해운대구  일반용   13784    421249988
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 5. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = GyeonGiHap2.loc[GyeonGiHap2['년월'] == '201601-201606']
GyeonGiHap2
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)   사용량(kWh)
# 96   201601-201606  부산광역시   강서구  일반용    8315  146640475
# 97   201601-201606  부산광역시   금정구  일반용   15213  193129614
# 98   201601-201606  부산광역시   기장군  일반용    7451  154318698
# 99   201601-201606  부산광역시    남구  일반용   11786  186998582
# 100  201601-201606  부산광역시    동구  일반용    7568  145413265
# 101  201601-201606  부산광역시   동래구  일반용   15638  208486551
# 102  201601-201606  부산광역시  부산진구  일반용   22992  399212282
# 103  201601-201606  부산광역시    북구  일반용   10591  170386802
# 104  201601-201606  부산광역시   사상구  일반용   13328  204013930
# 105  201601-201606  부산광역시   사하구  일반용   14250  200067413
# 106  201601-201606  부산광역시    서구  일반용    6660  110178461
# 107  201601-201606  부산광역시   수영구  일반용   10348  139809689
# 108  201601-201606  부산광역시   연제구  일반용   11008  186481527
# 109  201601-201606  부산광역시   영도구  일반용    6002   69463594
# 110  201601-201606  부산광역시    중구  일반용    9057  158469648
# 111  201601-201606  부산광역시  해운대구  일반용   13784  421249988

# %%
Final = pd.concat([GyeonGiHap2 , Hap])
Final = Final.sort_values('시군구')
Final
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   201601-201606  부산광역시   강서구  일반용    8315   146640475
# 96   201601-201606  부산광역시   강서구   합계    7779  1742712338
# 97   201601-201606  부산광역시   금정구   합계   17922   545536239
# 97   201601-201606  부산광역시   금정구  일반용   15213   193129614
# 98   201601-201606  부산광역시   기장군   합계    8296   535419051
# 98   201601-201606  부산광역시   기장군  일반용    7451   154318698
# 99   201601-201606  부산광역시    남구  일반용   11786   186998582
# 99   201601-201606  부산광역시    남구   합계   17050   693327724
# 100  201601-201606  부산광역시    동구  일반용    7568   145413265
# 100  201601-201606  부산광역시    동구   합계    8926   260806574
# 101  201601-201606  부산광역시   동래구  일반용   15638   208486551
# 101  201601-201606  부산광역시   동래구   합계   15860   460662256
# 102  201601-201606  부산광역시  부산진구  일반용   22992   399212282
# 102  201601-201606  부산광역시  부산진구   합계   23988   826792164
# 103  201601-201606  부산광역시    북구  일반용   10591   170386802
# 103  201601-201606  부산광역시    북구   합계   12783   448358142
# 104  201601-201606  부산광역시   사상구   합계   13491   923045256
# 104  201601-201606  부산광역시   사상구  일반용   13328   204013930
# 105  201601-201606  부산광역시   사하구   합계   18992  1396768767
# 105  201601-201606  부산광역시   사하구  일반용   14250   200067413
# 106  201601-201606  부산광역시    서구  일반용    6660   110178461
# 106  201601-201606  부산광역시    서구   합계   10339   286216697
# 107  201601-201606  부산광역시   수영구   합계   12000   285682846
# 107  201601-201606  부산광역시   수영구  일반용   10348   139809689
# 108  201601-201606  부산광역시   연제구   합계   12036   381377072
# 108  201601-201606  부산광역시   연제구  일반용   11008   186481527
# 109  201601-201606  부산광역시   영도구   합계    9811   241964917
# 109  201601-201606  부산광역시   영도구  일반용    6002    69463594
# 110  201601-201606  부산광역시    중구   합계    6203   204009233
# 110  201601-201606  부산광역시    중구  일반용    9057   158469648
# 111  201601-201606  부산광역시  해운대구  일반용   13784   421249988
# 111  201601-201606  부산광역시  해운대구   합계   15428   908269512

# %%
# Final['일반용 전기의 비율'] = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']) // (Final['사용량(kWh)'].loc[Final['계약구분'] == '합계'])
# Final
ex = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']).tolist()


ex
# Out:
# [146640475,
#  193129614,
#  154318698,
#  186998582,
#  145413265,
#  208486551,
#  399212282,
#  170386802,
#  204013930,
#  200067413,
#  110178461,
#  139809689,
#  186481527,
#  69463594,
#  158469648,
#  421249988]

# %%
ex_2 =(Final['사용량(kWh)'].loc[Final['계약구분'] == '합계']).tolist()
ex_2
# Out:
# [1742712338,
#  545536239,
#  535419051,
#  693327724,
#  260806574,
#  460662256,
#  826792164,
#  448358142,
#  923045256,
#  1396768767,
#  286216697,
#  285682846,
#  381377072,
#  241964917,
#  204009233,
#  908269512]

# %%
Rate = []
ilban = []
rae = 0
for i in range(len(ex)):
    rae = round(ex[i] / ex_2[i] *100 ,2)
    Rate.append(rae)
print(Rate)
# Out:
# [8.41, 35.4, 28.82, 26.97, 55.76, 45.26, 48.28, 38.0, 22.1, 14.32, 38.49, 48.94, 48.9, 28.71, 77.68, 46.38]

# %%
Rate3 = pd.Series(Rate)
Rate3

# Final = pd.concat([Final , Rate3])
# Final
# Out:
# 0     8
# 1    35
# 2    29
# 3    27
# 4    56
# 5    45
# 6    48
# 7    38
# 8    22
# 9    14
# 10   38
# 11   49
# 12   49
# 13   29
# 14   78
# 15   46
# dtype: float64

# %%
for j in range(len(Rate)):
    ilban.append('일반용')
#print(Rate)

Rate2 = pd.DataFrame()
Rate2['시군구'] = pd.DataFrame(SIGUNGU)
Rate2['계약구분'] = pd.DataFrame(ilban)
Rate2['비율'] = pd.DataFrame(Rate)
Rate2
#print(Rate2.dtypes)
# Out:
#      시군구 계약구분  비율
# 0    강서구  일반용   8
# 1    금정구  일반용  35
# 2    기장군  일반용  29
# 3     남구  일반용  27
# 4     동구  일반용  56
# 5    동래구  일반용  45
# 6   부산진구  일반용  48
# 7     북구  일반용  38
# 8    사상구  일반용  22
# 9    사하구  일반용  14
# 10    서구  일반용  38
# 11   수영구  일반용  49
# 12   연제구  일반용  49
# 13   영도구  일반용  29
# 14    중구  일반용  78
# 15  해운대구  일반용  46

# %%
Final = pd.merge(Final , Rate2, on=['시군구', '계약구분'] , how='left')

#Final.drop(['비율_y]' , axis = 1 , inplace = True)
#Final.rename(columns={'비율_y':'전체 계약종별 전력사용량 대비 일반용 사용량 비율'})
Final = Final.sort_values(['시군구' , '계약구분'])
Final
# Out:
#                년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)  비율
# 0   201601-201606  부산광역시   강서구  일반용    8315   146640475   8
# 1   201601-201606  부산광역시   강서구   합계    7779  1742712338 NaN
# 3   201601-201606  부산광역시   금정구  일반용   15213   193129614  35
# 2   201601-201606  부산광역시   금정구   합계   17922   545536239 NaN
# 5   201601-201606  부산광역시   기장군  일반용    7451   154318698  29
# 4   201601-201606  부산광역시   기장군   합계    8296   535419051 NaN
# 6   201601-201606  부산광역시    남구  일반용   11786   186998582  27
# 7   201601-201606  부산광역시    남구   합계   17050   693327724 NaN
# 8   201601-201606  부산광역시    동구  일반용    7568   145413265  56
# 9   201601-201606  부산광역시    동구   합계    8926   260806574 NaN
# 10  201601-201606  부산광역시   동래구  일반용   15638   208486551  45
# 11  201601-201606  부산광역시   동래구   합계   15860   460662256 NaN
# 12  201601-201606  부산광역시  부산진구  일반용   22992   399212282  48
# 13  201601-201606  부산광역시  부산진구   합계   23988   826792164 NaN
# 14  201601-201606  부산광역시    북구  일반용   10591   170386802  38
# 15  201601-201606  부산광역시    북구   합계   12783   448358142 NaN
# 17  201601-201606  부산광역시   사상구  일반용   13328   204013930  22
# 16  201601-201606  부산광역시   사상구   합계   13491   923045256 NaN
# 19  201601-201606  부산광역시   사하구  일반용   14250   200067413  14
# 18  201601-201606  부산광역시   사하구   합계   18992  1396768767 NaN
# 20  201601-201606  부산광역시    서구  일반용    6660   110178461  38
# 21  201601-201606  부산광역시    서구   합계   10339   286216697 NaN
# 23  201601-201606  부산광역시   수영구  일반용   10348   139809689  49
# 22  201601-201606  부산광역시   수영구   합계   12000   285682846 NaN
# 25  201601-201606  부산광역시   연제구  일반용   11008   186481527  49
# 24  201601-201606  부산광역시   연제구   합계   12036   381377072 NaN
# 27  201601-201606  부산광역시   영도구  일반용    6002    69463594  29
# 26  201601-201606  부산광역시   영도구   합계    9811   241964917 NaN
# 29  201601-201606  부산광역시    중구  일반용    9057   158469648  78
# 28  201601-201606  부산광역시    중구   합계    6203   204009233 NaN
# 30  201601-201606  부산광역시  해운대구  일반용   13784   421249988  46
# 31  201601-201606  부산광역시  해운대구   합계   15428   908269512 NaN

# %%
# Final['일반용 전기의 비율'] = Final.append(Rate)
# Final

# %% [markdown]
# ### 6. 날짜 체크!!!!!!!!!!!!!!!!!!!!1

# %%
Final.to_csv("{}_일반용_전력사용량_1601-06.csv".format(City) , mode = 'w' , encoding= 'cp949' , index =False) #파일명 수정

# %%
# Sigu = list(set(df_3['시군구'].tolist()))
#
# Sigu.sort()
#
# Sigu

# %%
# YearMonth = list(set(df_3['년월'].tolist()))
#
# YearMonth.sort()
# YearMonth

# %%
# Gayeak = list(set(df_3['계약구분'].tolist()))
#
# Gayeak.sort()
# Gayeak

# %%
# SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
# SEOUL.drop(['고객호수(호)' ,'전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
# #SEOUL.dtypes(['사용량(kWh)'])
# SEOUL

# %%
#SEOUL.to_csv("서울특별시_일반용_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
# print(SEOUL.dtypes)
# SEOUL = SEOUL.astype({'사용량(kWh)' : 'float'})

# %%
# SEOUL

# %%
# a = SEOUL['사용량(kWh)'].tolist()
# int_list = map(int, a)
# b=0
# for i in int_list:
#     b+=i
#
# print(b)
