# %%
import pandas as pd
import re

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ### 1. 꼭 read_csv 21상반기, 19하반기와 같이 맞추어 주세요!!! 또한 지역(전라북도, 남도) 맞추기!!!!!

# %%
df = pd.read_csv('부산광역시_계약종별 전력사용량 월별_19상반기.csv' , encoding='cp949')

df

#exchng=  pd.read_csv('지역별_전력거래량_20220803093050.csv' , encoding='cp949')
# Out:
#         계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0    시도 : 부산광역시, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1        기간 : 2019년 01 월 ~ 2019년 06월        NaN            NaN        NaN
# 2                                 년월         시구            시군구       계약구분
# 3                             201901      부산광역시  전체(시 / 군 / 구)        주택용
# 4                             201901      부산광역시  전체(시 / 군 / 구)        일반용
# ..                               ...        ...            ...        ...
# 811                           201906      부산광역시           해운대구        산업용
# 812                           201906      부산광역시           해운대구        심 야
# 813                           201906      부산광역시           해운대구        일반용
# 814                           201906      부산광역시           해운대구        주택용
# 815                           201906      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0          NaN           NaN              NaN            NaN
# 1          NaN           NaN              NaN            NaN
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     954,734   425,251,567   47,759,125,486          112.3
# 4     187,246   605,121,700   82,102,565,063          135.7
# ..         ...           ...              ...            ...
# 811       951    16,986,817    2,141,621,287          126.1
# 812       882     2,150,372      142,946,248           66.5
# 813    14,397    70,719,496    9,663,894,087          136.7
# 814    72,588    49,177,081    5,157,602,691          104.9
# 815    94,074   143,126,979   17,570,414,739          122.8
#
# [816 rows x 8 columns]

# %%
df = df.drop([0,1 , 46] , axis = 0)
#0,1 , 10은 지우는게 맞다
df
# Out:
#     계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 2                             년월         시구            시군구       계약구분
# 3                         201901      부산광역시  전체(시 / 군 / 구)        주택용
# 4                         201901      부산광역시  전체(시 / 군 / 구)        일반용
# 5                         201901      부산광역시  전체(시 / 군 / 구)        교육용
# 6                         201901      부산광역시  전체(시 / 군 / 구)        산업용
# ..                           ...        ...            ...        ...
# 811                       201906      부산광역시           해운대구        산업용
# 812                       201906      부산광역시           해운대구        심 야
# 813                       201906      부산광역시           해운대구        일반용
# 814                       201906      부산광역시           해운대구        주택용
# 815                       201906      부산광역시           해운대구         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     954,734   425,251,567   47,759,125,486          112.3
# 4     187,246   605,121,700   82,102,565,063          135.7
# 5       1,165    46,277,265    4,972,156,945          107.4
# 6      25,047   759,467,776   94,170,341,496          124.0
# ..         ...           ...              ...            ...
# 811       951    16,986,817    2,141,621,287          126.1
# 812       882     2,150,372      142,946,248           66.5
# 813    14,397    70,719,496    9,663,894,087          136.7
# 814    72,588    49,177,081    5,157,602,691          104.9
# 815    94,074   143,126,979   17,570,414,739          122.8
#
# [813 rows x 8 columns]

# %%
a= df.loc[2].tolist()
a
df = df.drop([2] , axis = 0)

# %%
df.columns = a
df
# Out:
#          년월     시구            시군구 계약구분   고객호수(호)      사용량(kWh)  \
# 3    201901  부산광역시  전체(시 / 군 / 구)  주택용  954,734   425,251,567
# 4    201901  부산광역시  전체(시 / 군 / 구)  일반용  187,246   605,121,700
# 5    201901  부산광역시  전체(시 / 군 / 구)  교육용    1,165    46,277,265
# 6    201901  부산광역시  전체(시 / 군 / 구)  산업용   25,047   759,467,776
# 7    201901  부산광역시  전체(시 / 군 / 구)  농사용   11,372    12,802,314
# ..      ...    ...            ...  ...       ...           ...
# 811  201906  부산광역시           해운대구  산업용      951    16,986,817
# 812  201906  부산광역시           해운대구  심 야      882     2,150,372
# 813  201906  부산광역시           해운대구  일반용   14,397    70,719,496
# 814  201906  부산광역시           해운대구  주택용   72,588    49,177,081
# 815  201906  부산광역시           해운대구   합계   94,074   143,126,979
#
#              전기요금(원) 평균판매단가(원/kWh)
# 3    47,759,125,486         112.3
# 4    82,102,565,063         135.7
# 5     4,972,156,945         107.4
# 6    94,170,341,496         124.0
# 7       622,880,233          48.7
# ..               ...           ...
# 811   2,141,621,287         126.1
# 812     142,946,248          66.5
# 813   9,663,894,087         136.7
# 814   5,157,602,691         104.9
# 815  17,570,414,739         122.8
#
# [812 rows x 8 columns]

# %%
df_2 = df.loc[:45]
df_2
# Out:
#         년월     시구            시군구 계약구분    고객호수(호)        사용량(kWh)  \
# 3   201901  부산광역시  전체(시 / 군 / 구)  주택용   954,734     425,251,567
# 4   201901  부산광역시  전체(시 / 군 / 구)  일반용   187,246     605,121,700
# 5   201901  부산광역시  전체(시 / 군 / 구)  교육용     1,165      46,277,265
# 6   201901  부산광역시  전체(시 / 군 / 구)  산업용    25,047     759,467,776
# 7   201901  부산광역시  전체(시 / 군 / 구)  농사용    11,372      12,802,314
# 8   201901  부산광역시  전체(시 / 군 / 구)  가로등    83,213      17,221,671
# 9   201901  부산광역시  전체(시 / 군 / 구)  심 야    20,749      40,669,674
# 10  201902  부산광역시  전체(시 / 군 / 구)  주택용   954,610     420,976,468
# 11  201902  부산광역시  전체(시 / 군 / 구)  일반용   187,301     567,072,823
# 12  201902  부산광역시  전체(시 / 군 / 구)  교육용     1,171      41,183,425
# 13  201902  부산광역시  전체(시 / 군 / 구)  산업용    25,052     655,771,401
# 14  201902  부산광역시  전체(시 / 군 / 구)  농사용    11,382      12,558,810
# 15  201902  부산광역시  전체(시 / 군 / 구)  가로등    82,865      16,495,852
# 16  201902  부산광역시  전체(시 / 군 / 구)  심 야    20,675      39,649,581
# 17  201903  부산광역시  전체(시 / 군 / 구)  주택용   954,863     363,540,446
# 18  201903  부산광역시  전체(시 / 군 / 구)  일반용   187,181     486,796,953
# 19  201903  부산광역시  전체(시 / 군 / 구)  교육용     1,171      37,769,385
# 20  201903  부산광역시  전체(시 / 군 / 구)  산업용    25,050     709,199,946
# 21  201903  부산광역시  전체(시 / 군 / 구)  농사용    11,546       9,339,112
# 22  201903  부산광역시  전체(시 / 군 / 구)  가로등    82,830      15,666,993
# 23  201903  부산광역시  전체(시 / 군 / 구)  심 야    20,599      29,723,775
# 24  201904  부산광역시  전체(시 / 군 / 구)  주택용   955,380     383,248,991
# 25  201904  부산광역시  전체(시 / 군 / 구)  일반용   187,075     487,305,402
# 26  201904  부산광역시  전체(시 / 군 / 구)  교육용     1,163      38,721,740
# 27  201904  부산광역시  전체(시 / 군 / 구)  산업용    25,051     711,122,998
# 28  201904  부산광역시  전체(시 / 군 / 구)  농사용    11,499       8,814,189
# 29  201904  부산광역시  전체(시 / 군 / 구)  가로등    82,965      14,669,092
# 30  201904  부산광역시  전체(시 / 군 / 구)  심 야    20,519      25,351,906
# 31  201905  부산광역시  전체(시 / 군 / 구)  주택용   955,317     355,929,263
# 32  201905  부산광역시  전체(시 / 군 / 구)  일반용   187,252     471,433,488
# 33  201905  부산광역시  전체(시 / 군 / 구)  교육용     1,162      31,741,642
# 34  201905  부산광역시  전체(시 / 군 / 구)  산업용    25,045     697,287,794
# 35  201905  부산광역시  전체(시 / 군 / 구)  농사용    11,498       7,595,573
# 36  201905  부산광역시  전체(시 / 군 / 구)  가로등    82,939      13,931,066
# 37  201905  부산광역시  전체(시 / 군 / 구)  심 야    20,395      18,148,995
# 38  201906  부산광역시  전체(시 / 군 / 구)  주택용   955,340     359,253,568
# 39  201906  부산광역시  전체(시 / 군 / 구)  일반용   187,339     508,789,648
# 40  201906  부산광역시  전체(시 / 군 / 구)  교육용     1,164      34,050,296
# 41  201906  부산광역시  전체(시 / 군 / 구)  산업용    25,058     696,294,712
# 42  201906  부산광역시  전체(시 / 군 / 구)  농사용    11,504       8,084,818
# 43  201906  부산광역시  전체(시 / 군 / 구)  가로등    82,938      13,185,172
# 44  201906  부산광역시  전체(시 / 군 / 구)  심 야    20,310      13,411,554
# 45      합계     합계             합계   합계  7,700,735  10,210,928,844
#
#               전기요금(원) 평균판매단가(원/kWh)
# 3     47,759,125,486         112.3
# 4     82,102,565,063         135.7
# 5      4,972,156,945         107.4
# 6     94,170,341,496         124.0
# 7        622,880,233          48.7
# 8      1,817,315,199         105.5
# 9      3,083,131,388          75.8
# 10    46,987,359,352         111.6
# 11    77,284,185,921         136.3
# 12     4,524,178,034         109.9
# 13    83,142,252,079         126.8
# 14       613,144,097          48.8
# 15     1,803,886,019         109.4
# 16     3,006,112,837          75.8
# 17    36,498,157,757         100.4
# 18    62,128,943,203         127.6
# 19     3,897,842,057         103.2
# 20    75,200,530,328         106.0
# 21       475,987,361          51.0
# 22     1,723,994,421         110.0
# 23     2,005,767,561          67.5
# 24    39,625,757,897         103.4
# 25    57,278,726,131         117.5
# 26     3,462,745,120          89.4
# 27    72,943,716,406         102.6
# 28       456,463,652          51.8
# 29     1,665,002,814         113.5
# 30     1,431,462,714          56.5
# 31    35,043,275,896          98.5
# 32    56,183,065,204         119.2
# 33     2,950,129,621          92.9
# 34    71,828,681,786         103.0
# 35       397,854,921          52.4
# 36     1,610,948,735         115.6
# 37     1,057,664,711          58.3
# 38    35,677,326,432          99.3
# 39    68,796,743,786         135.2
# 40     3,742,085,370         109.9
# 41    85,575,605,019         122.9
# 42       410,211,259          50.7
# 43     1,566,990,233         118.8
# 44       846,126,777          63.1
# 45  1,176,370,441,321         115.2

# %%
GyeonGi  = df_2.loc[(df_2['계약구분'] == '일반용')]
#SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
GyeonGi
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\730399353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
#         년월     시구 계약구분   고객호수(호)      사용량(kWh)
# 4   201901  부산광역시  일반용  187,246   605,121,700
# 11  201902  부산광역시  일반용  187,301   567,072,823
# 18  201903  부산광역시  일반용  187,181   486,796,953
# 25  201904  부산광역시  일반용  187,075   487,305,402
# 32  201905  부산광역시  일반용  187,252   471,433,488
# 39  201906  부산광역시  일반용  187,339   508,789,648

# %%
#SEOUL1.to_csv("서울특별시_계약종별_전국_전력사용량_2022.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df_2.to_csv("서울특별시_계약종별_전국_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
df_3 = df.loc[48:]
df_3 = df_3.loc[(df_3['계약구분'] == '일반용')]
df_3 = df_3.sort_values(by=['시군구' , '년월'])
df_3.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201901  부산광역시   강서구  일반용   9,621   39,458,151
# 181  201902  부산광역시   강서구  일반용   9,645   36,150,254
# 309  201903  부산광역시   강서구  일반용   9,661   32,506,038
# 437  201904  부산광역시   강서구  일반용   9,686   32,888,839
# 565  201905  부산광역시   강서구  일반용   9,693   32,068,610
# ..      ...    ...   ...  ...      ...          ...
# 301  201902  부산광역시  해운대구  일반용  14,346   72,912,238
# 429  201903  부산광역시  해운대구  일반용  14,313   66,156,202
# 557  201904  부산광역시  해운대구  일반용  14,322   64,961,466
# 685  201905  부산광역시  해운대구  일반용  14,345   66,122,832
# 813  201906  부산광역시  해운대구  일반용  14,397   70,719,496
#
# [96 rows x 6 columns]

# %%
a = df_3.loc[: , "시구"]
b = a[:1].tolist()
for i in b:
    City = i
City
# Out:
# '부산광역시'

# %%
SIGUNGU = list(set(df_3.loc[: , '시군구'].tolist()))
SIGUNGU.sort()
SIGUNGU
# Out:
# ['강서구',
#  '금정구',
#  '기장군',
#  '남구',
#  '동구',
#  '동래구',
#  '부산진구',
#  '북구',
#  '사상구',
#  '사하구',
#  '서구',
#  '수영구',
#  '연제구',
#  '영도구',
#  '중구',
#  '해운대구']

# %%
df_4 = df.loc[48:]
df_4 = df_4.loc[(df_4['계약구분'] == '합계')]
df_4 = df_4.sort_values(by=['시군구' , '년월'])
df_4.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_4
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 55   201901  부산광역시   강서구   합계  53,401   370,500,185
# 183  201902  부산광역시   강서구   합계  53,515   327,785,084
# 311  201903  부산광역시   강서구   합계  53,632   341,177,605
# 439  201904  부산광역시   강서구   합계  53,803   340,927,252
# 567  201905  부산광역시   강서구   합계  53,851   337,922,148
# ..      ...    ...   ...  ...      ...           ...
# 303  201902  부산광역시  해운대구   합계  93,918   153,772,409
# 431  201903  부산광역시  해운대구   합계  93,970   143,551,598
# 559  201904  부산광역시  해운대구   합계  94,019   142,793,018
# 687  201905  부산광역시  해운대구   합계  94,008   139,972,943
# 815  201906  부산광역시  해운대구   합계  94,074   143,126,979
#
# [96 rows x 6 columns]

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_4['사용량(kWh)'].loc[(df_4['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_4['고객호수(호)'].loc[(df_4['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//36) #6개월 치로 나눠야하나?!




print("{} 지역별 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# Out:
# [370500185, 327785084, 341177605, 340927252, 337922148, 339970862]
# [102767895, 97435570, 86436452, 88026277, 81962526, 84439782]
# [106484934, 97022794, 90177079, 89180691, 85760240, 86398234]
# [127846329, 118851321, 114964273, 113823148, 110613233, 113875901]
# [49707342, 46760665, 40792169, 41144882, 38459009, 39575050]
# [86383309, 83537552, 72057865, 73428821, 68626279, 71678169]
# [157878976, 149056897, 131410573, 132464231, 126637827, 132455720]
# [81901063, 78270436, 67678291, 69769214, 64718040, 67644864]
# [158140948, 146473905, 134740779, 140937406, 127550710, 128493657]
# [239584537, 208121799, 213602911, 218253755, 208158055, 211500479]
# [54600547, 48332877, 44645491, 45290616, 43646100, 44785205]
# [54804416, 53678961, 45493671, 46291793, 42813733, 45045993]
# [71156598, 67986466, 59197458, 60160041, 57239408, 60206661]
# [44155012, 41881011, 36323560, 37172294, 33792609, 34194358]
# [36925837, 34740613, 29786835, 29570879, 28194961, 29677854]
# [163974039, 153772409, 143551598, 142793018, 139972943, 143126979]
# 부산광역시 지역별 합계 :  [2058283136, 541068502, 555023972, 699974205, 256439117, 455711995, 829904224, 429981908, 836337405, 1299221536, 281300836, 288128567, 375946632, 227518844, 188896979, 887190986]
# 부산광역시 고객호수 평균:  [8945, 18657, 9149, 17010, 8839, 15541, 23237, 12935, 13777, 19475, 10194, 12580, 11937, 9648, 6317, 15660]

# %% [markdown]
# ### 2. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = df_4.copy()
Hap.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
Hap
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\1362649055.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분  고객호수(호)      사용량(kWh)
# 0           201901  부산광역시   강서구   합계  53,401   370,500,185
# 1           201902  부산광역시   강서구   합계  53,515   327,785,084
# 2           201903  부산광역시   강서구   합계  53,632   341,177,605
# 3           201904  부산광역시   강서구   합계  53,803   340,927,252
# 4           201905  부산광역시   강서구   합계  53,851   337,922,148
# ..             ...    ...   ...  ...      ...           ...
# 107  201901-201906  부산광역시   수영구   합계    12580     288128567
# 108  201901-201906  부산광역시   연제구   합계    11937     375946632
# 109  201901-201906  부산광역시   영도구   합계     9648     227518844
# 110  201901-201906  부산광역시    중구   합계     6317     188896979
# 111  201901-201906  부산광역시  해운대구   합계    15660     887190986
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 3. 날짜 변경!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = Hap.loc[Hap['년월'] == '201901-201906']
Hap
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   201901-201906  부산광역시   강서구   합계    8945  2058283136
# 97   201901-201906  부산광역시   금정구   합계   18657   541068502
# 98   201901-201906  부산광역시   기장군   합계    9149   555023972
# 99   201901-201906  부산광역시    남구   합계   17010   699974205
# 100  201901-201906  부산광역시    동구   합계    8839   256439117
# 101  201901-201906  부산광역시   동래구   합계   15541   455711995
# 102  201901-201906  부산광역시  부산진구   합계   23237   829904224
# 103  201901-201906  부산광역시    북구   합계   12935   429981908
# 104  201901-201906  부산광역시   사상구   합계   13777   836337405
# 105  201901-201906  부산광역시   사하구   합계   19475  1299221536
# 106  201901-201906  부산광역시    서구   합계   10194   281300836
# 107  201901-201906  부산광역시   수영구   합계   12580   288128567
# 108  201901-201906  부산광역시   연제구   합계   11937   375946632
# 109  201901-201906  부산광역시   영도구   합계    9648   227518844
# 110  201901-201906  부산광역시    중구   합계    6317   188896979
# 111  201901-201906  부산광역시  해운대구   합계   15660   887190986

# %%
# SIGUNGU = SIGUNGU[:1]
# SIGUNGU
#for i in SIGUNGU:
#print('{}'.format(i))
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
a = (df_3.columns).tolist()

a
# Out:
# ['년월', '시구', '시군구', '계약구분', '고객호수(호)', '사용량(kWh)']

# %%
df_3
# Out:
#          년월     시구   시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201901  부산광역시   강서구  일반용   9,621   39,458,151
# 181  201902  부산광역시   강서구  일반용   9,645   36,150,254
# 309  201903  부산광역시   강서구  일반용   9,661   32,506,038
# 437  201904  부산광역시   강서구  일반용   9,686   32,888,839
# 565  201905  부산광역시   강서구  일반용   9,693   32,068,610
# ..      ...    ...   ...  ...      ...          ...
# 301  201902  부산광역시  해운대구  일반용  14,346   72,912,238
# 429  201903  부산광역시  해운대구  일반용  14,313   66,156,202
# 557  201904  부산광역시  해운대구  일반용  14,322   64,961,466
# 685  201905  부산광역시  해운대구  일반용  14,345   66,122,832
# 813  201906  부산광역시  해운대구  일반용  14,397   70,719,496
#
# [96 rows x 6 columns]

# %%
# GyeonGiHap = pd.DataFrame([] , columns = a)
# GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{가평군}')]
# GyeonGiHap

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_3['고객호수(호)'].loc[(df_3['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//6) #6개월 치로 나눠야하나?!




print("{} 지역별 일반용 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# GyeonGiHap['합계'] = sum
#
# GyeonGiHap
# Out:
# [39458151, 36150254, 32506038, 32888839, 32068610, 34561202]
# [36340324, 34580838, 29339978, 29424072, 27794827, 30040169]
# [31102752, 29530936, 23027624, 22567134, 22386245, 23296103]
# [37051861, 34361153, 29906988, 30242307, 29393410, 31703717]
# [27828212, 25978645, 22814919, 22271218, 21388886, 22809487]
# [39482285, 37295770, 31417206, 31409746, 30179835, 33252443]
# [75396627, 71271535, 61174131, 60993531, 60057885, 65667046]
# [32229964, 30680262, 25296969, 25460296, 23976336, 26161162]
# [39817485, 37265537, 31242924, 32534176, 29662275, 32047557]
# [39410560, 37475460, 31085796, 31857891, 30066062, 32534073]
# [21154335, 19586189, 17600284, 17678378, 17076517, 17960418]
# [27909169, 26758939, 22388186, 22367006, 20969631, 22886294]
# [35397559, 32958351, 28366388, 28266585, 27302559, 29810958]
# [13957951, 13530911, 11401898, 11630212, 10819854, 11478297]
# [28741013, 26735805, 23071422, 22752545, 22167724, 23861226]
# [79843452, 72912238, 66156202, 64961466, 66122832, 70719496]
# 부산광역시 지역별 일반용 합계 :  [207633094, 187520208, 151910794, 192659436, 143091367, 203037285, 394560755, 163804989, 202569954, 202429842, 111056121, 143279225, 182102400, 72819123, 147329735, 420715686]
# 부산광역시 고객호수 평균:  [9664, 15531, 8140, 12121, 7350, 15568, 23030, 10599, 13160, 14423, 6409, 10751, 11289, 6065, 8787, 14339]

# %%
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
# GyeonGiHap = df_3.copy()
# GyeonGiHap.reset_index(drop=True , inplace = True)
# GyeonGiHap.append({'년월' : '202107-202112'  , '시구' : '경기도' , '시군구' : '가평군' , '계약구분' : '일반용' , '사용량(kWh)' : sum}, ignore_index=True)

# %%
# a=[]
# for i in SIGUNGU:
#     a.append(i)
#
# print(a)

# %% [markdown]
# ### 4. 년월 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = df_3.copy()
GyeonGiHap2.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
GyeonGiHap2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_6236\2798360716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201901-201906'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월     시구   시군구 계약구분 고객호수(호)     사용량(kWh)
# 0           201901  부산광역시   강서구  일반용  9,621   39,458,151
# 1           201902  부산광역시   강서구  일반용  9,645   36,150,254
# 2           201903  부산광역시   강서구  일반용  9,661   32,506,038
# 3           201904  부산광역시   강서구  일반용  9,686   32,888,839
# 4           201905  부산광역시   강서구  일반용  9,693   32,068,610
# ..             ...    ...   ...  ...     ...          ...
# 107  201901-201906  부산광역시   수영구  일반용   10751    143279225
# 108  201901-201906  부산광역시   연제구  일반용   11289    182102400
# 109  201901-201906  부산광역시   영도구  일반용    6065     72819123
# 110  201901-201906  부산광역시    중구  일반용    8787    147329735
# 111  201901-201906  부산광역시  해운대구  일반용   14339    420715686
#
# [112 rows x 6 columns]

# %% [markdown]
# ### 5. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = GyeonGiHap2.loc[GyeonGiHap2['년월'] == '201901-201906']
GyeonGiHap2
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)   사용량(kWh)
# 96   201901-201906  부산광역시   강서구  일반용    9664  207633094
# 97   201901-201906  부산광역시   금정구  일반용   15531  187520208
# 98   201901-201906  부산광역시   기장군  일반용    8140  151910794
# 99   201901-201906  부산광역시    남구  일반용   12121  192659436
# 100  201901-201906  부산광역시    동구  일반용    7350  143091367
# 101  201901-201906  부산광역시   동래구  일반용   15568  203037285
# 102  201901-201906  부산광역시  부산진구  일반용   23030  394560755
# 103  201901-201906  부산광역시    북구  일반용   10599  163804989
# 104  201901-201906  부산광역시   사상구  일반용   13160  202569954
# 105  201901-201906  부산광역시   사하구  일반용   14423  202429842
# 106  201901-201906  부산광역시    서구  일반용    6409  111056121
# 107  201901-201906  부산광역시   수영구  일반용   10751  143279225
# 108  201901-201906  부산광역시   연제구  일반용   11289  182102400
# 109  201901-201906  부산광역시   영도구  일반용    6065   72819123
# 110  201901-201906  부산광역시    중구  일반용    8787  147329735
# 111  201901-201906  부산광역시  해운대구  일반용   14339  420715686

# %%
Final = pd.concat([GyeonGiHap2 , Hap])
Final = Final.sort_values('시군구')
Final
# Out:
#                 년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)
# 96   201901-201906  부산광역시   강서구  일반용    9664   207633094
# 96   201901-201906  부산광역시   강서구   합계    8945  2058283136
# 97   201901-201906  부산광역시   금정구   합계   18657   541068502
# 97   201901-201906  부산광역시   금정구  일반용   15531   187520208
# 98   201901-201906  부산광역시   기장군   합계    9149   555023972
# 98   201901-201906  부산광역시   기장군  일반용    8140   151910794
# 99   201901-201906  부산광역시    남구  일반용   12121   192659436
# 99   201901-201906  부산광역시    남구   합계   17010   699974205
# 100  201901-201906  부산광역시    동구  일반용    7350   143091367
# 100  201901-201906  부산광역시    동구   합계    8839   256439117
# 101  201901-201906  부산광역시   동래구  일반용   15568   203037285
# 101  201901-201906  부산광역시   동래구   합계   15541   455711995
# 102  201901-201906  부산광역시  부산진구  일반용   23030   394560755
# 102  201901-201906  부산광역시  부산진구   합계   23237   829904224
# 103  201901-201906  부산광역시    북구  일반용   10599   163804989
# 103  201901-201906  부산광역시    북구   합계   12935   429981908
# 104  201901-201906  부산광역시   사상구   합계   13777   836337405
# 104  201901-201906  부산광역시   사상구  일반용   13160   202569954
# 105  201901-201906  부산광역시   사하구   합계   19475  1299221536
# 105  201901-201906  부산광역시   사하구  일반용   14423   202429842
# 106  201901-201906  부산광역시    서구  일반용    6409   111056121
# 106  201901-201906  부산광역시    서구   합계   10194   281300836
# 107  201901-201906  부산광역시   수영구   합계   12580   288128567
# 107  201901-201906  부산광역시   수영구  일반용   10751   143279225
# 108  201901-201906  부산광역시   연제구   합계   11937   375946632
# 108  201901-201906  부산광역시   연제구  일반용   11289   182102400
# 109  201901-201906  부산광역시   영도구   합계    9648   227518844
# 109  201901-201906  부산광역시   영도구  일반용    6065    72819123
# 110  201901-201906  부산광역시    중구   합계    6317   188896979
# 110  201901-201906  부산광역시    중구  일반용    8787   147329735
# 111  201901-201906  부산광역시  해운대구  일반용   14339   420715686
# 111  201901-201906  부산광역시  해운대구   합계   15660   887190986

# %%
# Final['일반용 전기의 비율'] = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']) // (Final['사용량(kWh)'].loc[Final['계약구분'] == '합계'])
# Final
ex = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']).tolist()


ex
# Out:
# [207633094,
#  187520208,
#  151910794,
#  192659436,
#  143091367,
#  203037285,
#  394560755,
#  163804989,
#  202569954,
#  202429842,
#  111056121,
#  143279225,
#  182102400,
#  72819123,
#  147329735,
#  420715686]

# %%
ex_2 =(Final['사용량(kWh)'].loc[Final['계약구분'] == '합계']).tolist()
ex_2
# Out:
# [2058283136,
#  541068502,
#  555023972,
#  699974205,
#  256439117,
#  455711995,
#  829904224,
#  429981908,
#  836337405,
#  1299221536,
#  281300836,
#  288128567,
#  375946632,
#  227518844,
#  188896979,
#  887190986]

# %%
Rate = []
ilban = []
rae = 0
for i in range(len(ex)):
    rae = round(ex[i] / ex_2[i] *100 ,2)
    Rate.append(rae)
print(Rate)
# Out:
# [10.09, 34.66, 27.37, 27.52, 55.8, 44.55, 47.54, 38.1, 24.22, 15.58, 39.48, 49.73, 48.44, 32.01, 77.99, 47.42]

# %%
Rate3 = pd.Series(Rate)
Rate3

# Final = pd.concat([Final , Rate3])
# Final
# Out:
# 0    10
# 1    35
# 2    27
# 3    28
# 4    56
# 5    45
# 6    48
# 7    38
# 8    24
# 9    16
# 10   39
# 11   50
# 12   48
# 13   32
# 14   78
# 15   47
# dtype: float64

# %%
for j in range(len(Rate)):
    ilban.append('일반용')
#print(Rate)

Rate2 = pd.DataFrame()
Rate2['시군구'] = pd.DataFrame(SIGUNGU)
Rate2['계약구분'] = pd.DataFrame(ilban)
Rate2['비율'] = pd.DataFrame(Rate)
Rate2
#print(Rate2.dtypes)
# Out:
#      시군구 계약구분  비율
# 0    강서구  일반용  10
# 1    금정구  일반용  35
# 2    기장군  일반용  27
# 3     남구  일반용  28
# 4     동구  일반용  56
# 5    동래구  일반용  45
# 6   부산진구  일반용  48
# 7     북구  일반용  38
# 8    사상구  일반용  24
# 9    사하구  일반용  16
# 10    서구  일반용  39
# 11   수영구  일반용  50
# 12   연제구  일반용  48
# 13   영도구  일반용  32
# 14    중구  일반용  78
# 15  해운대구  일반용  47

# %%
Final = pd.merge(Final , Rate2, on=['시군구', '계약구분'] , how='left')

#Final.drop(['비율_y]' , axis = 1 , inplace = True)
#Final.rename(columns={'비율_y':'전체 계약종별 전력사용량 대비 일반용 사용량 비율'})
Final = Final.sort_values(['시군구' , '계약구분'])
Final
# Out:
#                년월     시구   시군구 계약구분 고객호수(호)    사용량(kWh)  비율
# 0   201901-201906  부산광역시   강서구  일반용    9664   207633094  10
# 1   201901-201906  부산광역시   강서구   합계    8945  2058283136 NaN
# 3   201901-201906  부산광역시   금정구  일반용   15531   187520208  35
# 2   201901-201906  부산광역시   금정구   합계   18657   541068502 NaN
# 5   201901-201906  부산광역시   기장군  일반용    8140   151910794  27
# 4   201901-201906  부산광역시   기장군   합계    9149   555023972 NaN
# 6   201901-201906  부산광역시    남구  일반용   12121   192659436  28
# 7   201901-201906  부산광역시    남구   합계   17010   699974205 NaN
# 8   201901-201906  부산광역시    동구  일반용    7350   143091367  56
# 9   201901-201906  부산광역시    동구   합계    8839   256439117 NaN
# 10  201901-201906  부산광역시   동래구  일반용   15568   203037285  45
# 11  201901-201906  부산광역시   동래구   합계   15541   455711995 NaN
# 12  201901-201906  부산광역시  부산진구  일반용   23030   394560755  48
# 13  201901-201906  부산광역시  부산진구   합계   23237   829904224 NaN
# 14  201901-201906  부산광역시    북구  일반용   10599   163804989  38
# 15  201901-201906  부산광역시    북구   합계   12935   429981908 NaN
# 17  201901-201906  부산광역시   사상구  일반용   13160   202569954  24
# 16  201901-201906  부산광역시   사상구   합계   13777   836337405 NaN
# 19  201901-201906  부산광역시   사하구  일반용   14423   202429842  16
# 18  201901-201906  부산광역시   사하구   합계   19475  1299221536 NaN
# 20  201901-201906  부산광역시    서구  일반용    6409   111056121  39
# 21  201901-201906  부산광역시    서구   합계   10194   281300836 NaN
# 23  201901-201906  부산광역시   수영구  일반용   10751   143279225  50
# 22  201901-201906  부산광역시   수영구   합계   12580   288128567 NaN
# 25  201901-201906  부산광역시   연제구  일반용   11289   182102400  48
# 24  201901-201906  부산광역시   연제구   합계   11937   375946632 NaN
# 27  201901-201906  부산광역시   영도구  일반용    6065    72819123  32
# 26  201901-201906  부산광역시   영도구   합계    9648   227518844 NaN
# 29  201901-201906  부산광역시    중구  일반용    8787   147329735  78
# 28  201901-201906  부산광역시    중구   합계    6317   188896979 NaN
# 30  201901-201906  부산광역시  해운대구  일반용   14339   420715686  47
# 31  201901-201906  부산광역시  해운대구   합계   15660   887190986 NaN

# %%
# Final['일반용 전기의 비율'] = Final.append(Rate)
# Final

# %% [markdown]
# ### 6. 날짜 체크!!!!!!!!!!!!!!!!!!!!1

# %%
Final.to_csv("{}_일반용_전력사용량_1901-06.csv".format(City) , mode = 'w' , encoding= 'cp949' , index =False) #파일명 수정

# %%
# Sigu = list(set(df_3['시군구'].tolist()))
#
# Sigu.sort()
#
# Sigu

# %%
# YearMonth = list(set(df_3['년월'].tolist()))
#
# YearMonth.sort()
# YearMonth

# %%
# Gayeak = list(set(df_3['계약구분'].tolist()))
#
# Gayeak.sort()
# Gayeak

# %%
# SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
# SEOUL.drop(['고객호수(호)' ,'전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
# #SEOUL.dtypes(['사용량(kWh)'])
# SEOUL

# %%
#SEOUL.to_csv("서울특별시_일반용_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
# print(SEOUL.dtypes)
# SEOUL = SEOUL.astype({'사용량(kWh)' : 'float'})

# %%
# SEOUL

# %%
# a = SEOUL['사용량(kWh)'].tolist()
# int_list = map(int, a)
# b=0
# for i in int_list:
#     b+=i
#
# print(b)
